# %% [markdown]
# # Total Drug Cases

# %% [markdown]
# *Started running at: 20:30*

# %% [markdown]
# ## Config
# This code imports libraries that are used in the script and defines the variables that will be used in the script, such as the API url, the maximum number of cases to retrieve, the directory locations to save the data and the date range to filter the cases. It also creates the necessary directories if they do not exist. Additionally, it sets options to avoid certain errors in the Pandas library, such as chained assignment and future warnings.

# %%
# %pip install lxml -q
# %pip install numpy -q
# %pip install folium -q
# %pip install geopy -q

# %%
import csv
import requests
import json
import re
import urllib.request
import os
import re
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import clear_output
import matplotlib.pyplot as plt
from threading import Thread
from datetime import datetime, timedelta
import zipfile
import io
import warnings
from nltk.corpus import stopwords
dutch_stopwords = stopwords.words("dutch")
import time
import numpy as np

# %%
query = 'drugs handel'
base_verdicts_url = 'https://uitspraken.rechtspraak.nl/api/zoek?'
complete_case_url = 'https://data.rechtspraak.nl/uitspraken/content?id='
case_count = 15000 ## Amount of cases to retrieve. If you want max, just do an insanely high number, it stops when it fetched all cases. Backend does not accept values like 'max'.
location_initial_dataset = os.getcwd() + '/court case data/' 
location_cases = os.getcwd() + '/court case data/cases/' 
location_charts= os.getcwd() + '/charts/' 
cases_df = pd.DataFrame()
date_format = "%d-%m-%Y"
start_date = datetime.strptime('01-01-1905', date_format)
end_date = datetime.strptime('01-12-2022', date_format)


files = {
        "StartRow": 0,
        "PageSize": case_count,
        "ShouldReturnHighlights":'true',
        "ShouldCountFacets":'true',
        "SortOrder":"Relevance",
        "SearchTerms":[{"Term":query,"Field":"AlleVelden"}],
        "Contentsoorten":[],
        "Rechtsgebieden":[],
        "Instanties":[],
        "DatumPublicatie":[],
        "DatumUitspraak":[],
        "Advanced":{"PublicatieStatus":"AlleenGepubliceerd"},
        "CorrelationId":"9abc658b0ce64f8786992af6965aabc4",
        "Proceduresoorten":[]
    }

# create needed directories
directories = [location_initial_dataset, location_cases, location_charts]

for directory in directories:
    if not os.path.exists(directory):
        os.makedirs(directory)
        
# Avoiding some errors
pd.options.mode.chained_assignment = None 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Collecting Relevant Cases Using  Rechtspraak API
#
# This script retrieves court case data from Recchtspraak API and stores the data in a csv file (initial_dataset.csv) and individual txt files which includes the verdict part of the cases. The script has 3 main functions: get_cases(), create_cases_df(), and save_case_text(). The get_cases() function makes a post request to an API with a specific configuration (see config part), filters it by date, and returns a list of cases. The create_cases_df() function takes the list of cases and creates a pandas data frame with specific columns, then saves the data frame to a csv file. The save_case_text() function iterates through the cases in the dataframe (initial_dataset.csv) and makes a get request to the API to retrieve additional details (case text) for each case, then parses and saves the details in individual txt files.

# %%
def get_cases(config):
    try:
        response = requests.post(base_verdicts_url, json=config)
        responseJSON = json.loads(response.text)
        results0 = responseJSON['Results']
        results = []
        for item in results0:
            print(item ["TitelEmphasis"].replace(":", "-"))
            if item ["TitelEmphasis"].replace(":", "-") and datetime.strptime(item['Publicatiedatum'], date_format) >= start_date <= end_date:
                results.append(item)
        print(len(results), "records found.")       
        return results
    except urllib.error.HTTPError as err:
        print(err)    

def create_cases_df(cases):
    # create the DataFrame with specified columns
    index = ["id", "verdict_date", "publication_date", "verdict_type", "jurisdiction_type", "inhoudsindicatie"]
    cases_df = pd.DataFrame(columns = index)
    # loop through the cases and append each case as a new row in the DataFrame
    for case in cases:
        curr_case = pd.Series([case["TitelEmphasis"].replace(":", "-"), case["Uitspraakdatum"], case["Publicatiedatum"], case["UitspraakdatumType"], case["Rechtsgebieden"], case["Tekstfragment"]], index = index)
        cases_df = cases_df.append(curr_case, ignore_index=True) 
    # save the DataFrame to a CSV file in the directory './court case data/'
    cases_df.to_csv(location_initial_dataset+'initial_dataset.csv', index=False)
    return cases_df    

def save_case_text(df):
    # Iterate through the cases in the dataframe
    for case in df["id"]:
        try:
            # Make a request to get the case details
            response = requests.get(complete_case_url + case.replace("-", ":"))
            soup = BeautifulSoup(response.text, features="xml")
            uitspraak_xml = None
            # Check if the uitspraak element exists, if not check for conclusie
            if soup.find('uitspraak') is not None:
                uitspraak_xml = soup.find('uitspraak')
            elif soup.find('uitspraak') is None and soup.find('conclusie') is not None:
                uitspraak_xml = soup.find('conclusie')
            # Get the text of the uitspraak or conclusie element and replace commas
            uitspraak = uitspraak_xml.get_text()
            uitspraak = uitspraak.replace(',', '')
            # Replace colons with dashes to use as file name
            parsed_id = case.replace(":", "-")
            # Open a file in the location_cases directory with the parsed_id as the name
            with open(location_cases + parsed_id + ".txt", "w+", encoding='utf-8') as f:
                # Write the uitspraak text to the file
                f.write(uitspraak)
        except Exception as e:
            print(f"Error in saving case {case}. {e}")
    print("Finished")
    
cases = get_cases(files)
cases_df = create_cases_df(cases)
save_case_text(cases_df)
# Out:
# ECLI-NL-RBDHA-2019-9384
# ECLI-NL-RBMNE-2014-7289
# ECLI-NL-RBUTR-2008-BG6691
# ECLI-NL-RBNNE-2013-1693
# ECLI-NL-RBAMS-2015-3865
# ECLI-NL-RBROT-2014-9162
# ECLI-NL-CRVB-2004-AO7398
# ECLI-NL-RBNHO-2022-6623
# ECLI-NL-GHAMS-2016-1885
# ECLI-NL-CRVB-2010-BO3824
# ECLI-NL-RBZWB-2015-6574
# ECLI-NL-RBDHA-2015-1971
# ECLI-NL-RBALM-2012-BV9811
# ECLI-NL-CRVB-2006-AW7291
# ECLI-NL-HR-2007-BA1113
# ECLI-NL-PHR-2007-BA1113
# ECLI-NL-GHAMS-2016-4386
# ECLI-NL-RBAMS-2019-4296
# ECLI-NL-RBMAA-2010-BM8942
# ECLI-NL-RBMAA-2010-BM8944
# ECLI-NL-RBMAA-2010-BM8946
# ECLI-NL-RBLIM-2022-9412
# ECLI-NL-RBUTR-2011-BQ0665
# ECLI-NL-GHAMS-2019-585
# ECLI-NL-RBUTR-2011-BV5349
# ECLI-NL-RBUTR-2011-BV5471
# ECLI-NL-RBROT-2021-10718
# ECLI-NL-RBAMS-2018-2843
# ECLI-NL-PHR-2003-AK3618
# ECLI-NL-HR-2003-AK3618
# ECLI-NL-CRVB-2004-AR3605
# ECLI-NL-RBZWB-2022-5151
# ECLI-NL-GHAMS-2018-4059
# ECLI-NL-RBNNE-2019-167
# ECLI-NL-GHAMS-2017-4817
# ECLI-NL-RBAMS-2015-3864
# ECLI-NL-CRVB-2010-BN3889
# ECLI-NL-CRVB-2019-2745
# ECLI-NL-GHSHE-2014-683
# ECLI-NL-RBLIM-2022-9411
# ECLI-NL-CRVB-2003-AO5312
# ECLI-NL-GHAMS-2022-3125
# ECLI-NL-CRVB-2010-BN8774
# ECLI-NL-RBROT-2019-5629
# ECLI-NL-RBZUT-2008-BG8223
# ECLI-NL-RBROT-2020-12543
# ECLI-NL-RBSHE-2010-BO6588
# ECLI-NL-RBOVE-2014-6488
# ECLI-NL-RBROT-2022-9457
# ECLI-NL-RBMNE-2020-5510
# ECLI-NL-GHSHE-2017-5106
# ECLI-NL-GHDHA-2013-3408
# ECLI-NL-RBNHO-2020-2753
# ECLI-NL-RBROT-2018-5901
# ECLI-NL-RBUTR-2008-BC8607
# ECLI-NL-RBOVE-2021-3298
# ECLI-NL-RBAMS-2017-4741
# ECLI-NL-GHAMS-2019-587
# ECLI-NL-RBOBR-2013-BZ9550
# ECLI-NL-GHAMS-2004-AO4870
# ECLI-NL-RBOBR-2018-1915
# ECLI-NL-RBMNE-2020-3306
# ECLI-NL-RBOVE-2019-2402
# ECLI-NL-RBGEL-2019-1781
# ECLI-NL-RBLEE-2003-AH8846
# ECLI-NL-GHAMS-2000-AE9770
# ECLI-NL-RBNHO-2020-2746
# ECLI-NL-RBNHO-2020-2747
# ECLI-NL-RBNHO-2020-2748
# ECLI-NL-RBDHA-2019-9680
# ECLI-NL-GHSHE-2018-2676
# ECLI-NL-RBROT-2020-12469
# ECLI-NL-RBNNE-2017-641
# ECLI-NL-RBOBR-2015-1453
# ECLI-NL-RBMNE-2020-3307
# ECLI-NL-RBAMS-2017-6173
# ECLI-NL-CRVB-2011-BU9160
# ECLI-NL-CRVB-2006-AY8811
# ECLI-NL-RBLEE-2003-AH8847
# ECLI-NL-RBROT-2019-5628
# ECLI-NL-RBDHA-2022-3510
# ECLI-NL-RBSGR-2004-AR2800
# ECLI-NL-GHSGR-2004-AO7896
# ECLI-NL-RBOBR-2018-1667
# ECLI-NL-RBOVE-2022-1125
# ECLI-NL-RBSGR-2012-BX6161
# ECLI-NL-RBZWB-2021-1203
# ECLI-NL-RBZUT-2003-AH9598
# ECLI-NL-RBAMS-2022-817
# ECLI-NL-CRVB-2020-1454
# ECLI-NL-GHAMS-2003-AO2771
# ECLI-NL-RBSHE-2008-BC4804
# ECLI-NL-RBNNE-2019-4566
# ECLI-NL-GHAMS-2022-3126
# ECLI-NL-GHAMS-2019-3858
# ECLI-NL-GHAMS-2019-1602
# ECLI-NL-GHAMS-2019-1601
# ECLI-NL-RBNNE-2021-5018
# ECLI-NL-RBAMS-2019-4297
# ECLI-NL-GHAMS-2018-5202
# ECLI-NL-RBAMS-2021-1756
# ECLI-NL-RBOVE-2021-2603
# ECLI-NL-RBOVE-2021-2607
# ECLI-NL-RBOVE-2021-2606
# ECLI-NL-RBAMS-2020-6043
# ECLI-NL-RBGEL-2014-494
# ECLI-NL-RBGEL-2014-496
# ECLI-NL-RBGEL-2014-493
# ECLI-NL-CRVB-2013-BZ5597
# ECLI-NL-RBROT-2012-BY6936
# ECLI-NL-RBGRO-2009-BI0982
# ECLI-NL-RBLIM-2020-8160
# ECLI-NL-RBMAA-2011-BP1646
# ECLI-NL-RBZWB-2020-2646
# ECLI-NL-RBROT-2019-5630
# ECLI-NL-CRVB-2019-3966
# ECLI-NL-RBMNE-2014-7287
# ECLI-NL-RBMAA-2008-BD6613
# ECLI-NL-RBMAA-2008-BD2311
# ECLI-NL-RBROT-2019-5627
# ECLI-NL-HR-2016-1327
# ECLI-NL-PHR-2016-539
# ECLI-NL-RBUTR-2008-BC8605
# ECLI-NL-RBAMS-2017-9452
# ECLI-NL-GHAMS-2020-4069
# ECLI-NL-GHARL-2020-6067
# ECLI-NL-GHAMS-2010-BO9667
# ECLI-NL-RBARN-2009-BI0603
# ECLI-NL-RBNNE-2021-5026
# ECLI-NL-RBAMS-2019-7573
# ECLI-NL-RBROT-2021-13101
# ECLI-NL-RBNHO-2020-2745
# ECLI-NL-GHARL-2014-3990
# ECLI-NL-RBZLY-2012-BW3231
# ECLI-NL-RBMNE-2021-4252
# ECLI-NL-OGHACMB-2018-269
# ECLI-NL-RBAMS-2017-9087
# ECLI-NL-RBAMS-2017-9085
# ECLI-NL-RBAMS-2017-9086
# ECLI-NL-RBROT-2019-4922
# ECLI-NL-RBNNE-2019-4418
# ECLI-NL-RBROT-2019-5631
# ECLI-NL-RBAMS-2017-9092
# ECLI-NL-RBAMS-2017-9088
# ECLI-NL-RBAMS-2017-9090
# ECLI-NL-RBAMS-2017-9089
# ECLI-NL-RBASS-2009-BJ9607
# ECLI-NL-RBAMS-2017-9091
# ECLI-NL-OGEAC-2018-353
# ECLI-NL-RBROT-2019-5134
# ECLI-NL-RBAMS-2017-594
# ECLI-NL-OGEAC-2015-10
# ECLI-NL-GHAMS-2020-4100
# ECLI-NL-GHSHE-2021-2069
# ECLI-NL-RBALM-2012-BW4441
# ECLI-NL-RBLIM-2022-3264
# ECLI-NL-RBROT-2017-10355
# ECLI-NL-GHAMS-2018-2662
# ECLI-NL-RBUTR-2012-BX4202
# ECLI-NL-OGHACMB-2018-276
# ECLI-NL-OGEABES-2018-48
# ECLI-NL-RBROT-2017-10333
# ECLI-NL-RBMAA-2008-BD6609
# ECLI-NL-RBALM-2007-BB1611
# ECLI-NL-RBOVE-2021-4508
# ECLI-NL-OGEAC-2018-354
# ECLI-NL-OGHACMB-2019-157
# ECLI-NL-RBMNE-2013-BZ4568
# ECLI-NL-RVS-2020-1432
# ECLI-NL-RBNHO-2020-6998
# ECLI-NL-GHSGR-2003-AN8754
# ECLI-NL-RBROT-2022-9957
# ECLI-NL-RBMID-2005-AU5995
# ECLI-NL-RBLEE-2010-BL3692
# ECLI-NL-RBMNE-2022-1409
# ECLI-NL-RBAMS-2021-7806
# ECLI-NL-RBOVE-2022-565
# ECLI-NL-RBOVE-2021-1700
# ECLI-NL-RBOBR-2018-1916
# ECLI-NL-RBMAA-2008-BD6611
# ECLI-NL-GHAMS-2003-AF6966
# ECLI-NL-RBROT-2021-11929
# ECLI-NL-RBMNE-2013-BZ4552
# ECLI-NL-GHAMS-2019-2802
# ECLI-NL-GHAMS-2017-290
# ECLI-NL-GHAMS-2016-3483
# ECLI-NL-GHAMS-2016-3487
# ECLI-NL-RBDHA-2020-11915
# ECLI-NL-RBGEL-2021-554
# ECLI-NL-RBMID-2005-AU5992
# ECLI-NL-RBMNE-2020-5624
# ECLI-NL-GHAMS-2016-3484
# ECLI-NL-RBMNE-2020-5771
# ECLI-NL-RBOVE-2014-5830
# ECLI-NL-GHAMS-2011-BQ8115
# ECLI-NL-GHAMS-2014-2245
# ECLI-NL-RBAMS-2020-3535
# ECLI-NL-ORBAACM-2022-13
# ECLI-NL-RBAMS-2021-420
# ECLI-NL-RBOVE-2020-2545
# ECLI-NL-RVS-2019-2972
# ECLI-NL-RBNNE-2018-4794
# ECLI-NL-RBUTR-2008-BC8588
# ECLI-NL-RBSGR-2004-AR2799
# ECLI-NL-RBSGR-2004-AO9187
# ECLI-NL-RBSGR-2003-AM2562
# ECLI-NL-RBMNE-2015-5694
# ECLI-NL-RBROT-2022-5668
# ECLI-NL-RBDHA-2014-9303
# ECLI-NL-RBBRE-2007-BA3363
# ECLI-NL-RBDHA-2017-6510
# ECLI-NL-RBDHA-2017-6511
# ECLI-NL-CRVB-2013-CA1971
# ECLI-NL-RBMNE-2022-1408
# ECLI-NL-OGEAC-2019-141
# ECLI-NL-OGHACMB-2011-BP7461
# ECLI-NL-RBAMS-2021-571
# ECLI-NL-GHAMS-2014-1537
# ECLI-NL-RBAMS-2014-2171
# ECLI-NL-GHSHE-2004-AP1036
# ECLI-NL-RBLEE-2010-BL3686
# ECLI-NL-RBOBR-2019-2029
# ECLI-NL-CRVB-2014-3673
# ECLI-NL-RBNNE-2023-118
# ECLI-NL-RBNHO-2020-2749
# ECLI-NL-RBLIM-2019-4834
# ECLI-NL-RBAMS-2014-2172
# ECLI-NL-RBZWB-2017-7685
# ECLI-NL-RBDHA-2017-7971
# ECLI-NL-RBOVE-2022-2156
# ECLI-NL-RBDHA-2017-9524
# ECLI-NL-GHAMS-2014-1575
# ECLI-NL-GHSHE-2020-2751
# ECLI-NL-RBDHA-2018-9300
# ECLI-NL-RBNHO-2023-40
# ECLI-NL-GHSHE-2018-1422
# ECLI-NL-RBAMS-2020-3448
# ECLI-NL-RBDHA-2014-10768
# ECLI-NL-OGHNAA-2010-BM7471
# ECLI-NL-OGEAM-2016-114
# ECLI-NL-RBGEL-2020-4174
# ECLI-NL-GHAMS-2016-1868
# ECLI-NL-GHAMS-2016-1869
# ECLI-NL-RBUTR-2007-BC0812
# ECLI-NL-OGHACMB-2010-BP2903
# ECLI-NL-RBROT-2022-9842
# ECLI-NL-RBUTR-2011-BV5230
# ECLI-NL-RBROT-2021-12335
# ECLI-NL-GHSGR-2010-BN5646
# ECLI-NL-RBROT-2019-8229
# ECLI-NL-RBNNE-2017-807
# ECLI-NL-RBSGR-2011-BR5026
# ECLI-NL-RBROT-2017-10354
# ECLI-NL-OGHNAA-2010-BO0092
# ECLI-NL-RBMNE-2018-6462
# ECLI-NL-RBGEL-2016-3348
# ECLI-NL-RBLIM-2022-8796
# ECLI-NL-RBDHA-2022-7667
# ECLI-NL-RBGEL-2021-6998
# ECLI-NL-RBOVE-2020-882
# ECLI-NL-RBOVE-2019-3242
# ECLI-NL-RBLIM-2017-6756
# ECLI-NL-RBMID-2003-AN8464
# ECLI-NL-RBAMS-2019-6196
# ECLI-NL-RBROT-2017-10356
# ECLI-NL-CRVB-2021-2569
# ECLI-NL-RBARN-2011-BU4631
# ECLI-NL-OGHACMB-2020-319
# ECLI-NL-RBGEL-2015-6183
# ECLI-NL-RBZUT-2012-BW7681
# ECLI-NL-RBMNE-2020-5643
# ECLI-NL-RBAMS-2021-992
# ECLI-NL-RBROT-2017-10364
# ECLI-NL-RBDHA-2022-7461
# ECLI-NL-RBMNE-2020-5619
# ECLI-NL-RBMNE-2020-5621
# ECLI-NL-RBDHA-2022-7426
# ECLI-NL-RBMNE-2014-4798
# ECLI-NL-GHSHE-2013-404
# ECLI-NL-RBNNE-2016-5149
# ECLI-NL-GHSGR-2011-BU1302
# ECLI-NL-RBMAA-2011-BU7452
# ECLI-NL-RBUTR-2012-BX2971
# ECLI-NL-GHDHA-2022-1960
# ECLI-NL-RBALK-2007-BA0820
# ECLI-NL-RBUTR-2011-BR2562
# ECLI-NL-RBROT-2021-12804
# ECLI-NL-RBUTR-2009-BL7416
# ECLI-NL-RBROT-2021-12330
# ECLI-NL-RBLIM-2013-3877
# ECLI-NL-RBAMS-2019-8226
# ECLI-NL-RBALK-2007-BA0816
# ECLI-NL-RBAMS-2021-3455
# ECLI-NL-RBDHA-2021-559
# ECLI-NL-RBBRE-2005-AS5640
# ECLI-NL-GHAMS-2020-1666
# ECLI-NL-RBROT-2019-10918
# ECLI-NL-GHSHE-2014-3538
# ECLI-NL-RBASS-2002-AF1854
# ECLI-NL-RBHAA-2009-BL1056
# ECLI-NL-RBNNE-2016-5151
# ECLI-NL-RBLIM-2017-6753
# ECLI-NL-RBAMS-2021-3457
# ECLI-NL-GHSHE-2019-4348
# ECLI-NL-RBROT-2017-10225
# ECLI-NL-HR-2016-2069
# ECLI-NL-PHR-2016-890
# ECLI-NL-RBOBR-2016-2235
# ECLI-NL-RBMNE-2020-5645
# ECLI-NL-RBMNE-2013-CA1249
# ECLI-NL-RBROT-2003-AI0298
# ECLI-NL-RBROT-2018-6609
# ECLI-NL-RBOBR-2022-3966
# ECLI-NL-RBROT-2021-1234
# ECLI-NL-RBROT-2020-5432
# ECLI-NL-GHSHE-2010-BM0974
# ECLI-NL-RBGEL-2019-5449
# ECLI-NL-RBROT-2021-9637
# ECLI-NL-RBLEE-2008-BD3362
# ECLI-NL-RBAMS-2021-3453
# ECLI-NL-GHAMS-2022-799
# ECLI-NL-GHAMS-2011-BQ8109
# ECLI-NL-GHARL-2017-11540
# ECLI-NL-RBUTR-2011-BP9260
# ECLI-NL-GHAMS-2008-BC5072
# ECLI-NL-GHSHE-2013-6079
# ECLI-NL-RBSHE-2012-BV7944
# ECLI-NL-RBSHE-2010-BM6814
# ECLI-NL-RBAMS-2021-3456
# ECLI-NL-RBNNE-2017-338
# ECLI-NL-GHAMS-2004-AT7212
# ECLI-NL-RBOVE-2014-4047
# ECLI-NL-RBOVE-2021-3587
# ECLI-NL-RBROE-2012-BW3517
# ECLI-NL-RBZUT-2007-AZ7299
# ECLI-NL-GHAMS-2013-33
# ECLI-NL-GHAMS-2019-1758
# ECLI-NL-RBAMS-2022-2980
# ECLI-NL-RBGEL-2019-4371
# ECLI-NL-RBNHO-2020-7570
# ECLI-NL-RBLIM-2020-9774
# ECLI-NL-RBAMS-2018-8483
# ECLI-NL-RBZUT-2007-AZ7293
# ECLI-NL-RBAMS-2020-4809
# ECLI-NL-RBROE-2012-BW1010
# ECLI-NL-RBMAA-2011-BU7453
# ECLI-NL-RBROE-2012-BW8261
# ECLI-NL-RBAMS-2016-9038
# ECLI-NL-RBROT-2018-901
# ECLI-NL-HR-2017-1078
# ECLI-NL-PHR-2017-436
# ECLI-NL-RBASS-2006-AZ0704
# ECLI-NL-RBBRE-2005-AS4119
# ECLI-NL-RBMNE-2019-5869
# ECLI-NL-GHDHA-2022-1675
# ECLI-NL-RBBRE-2005-AS5645
# ECLI-NL-RBNNE-2019-2815
# ECLI-NL-RBAMS-2021-6050
# ECLI-NL-RBAMS-2021-6430
# ECLI-NL-RBROT-2022-8315
# ECLI-NL-RBGEL-2019-5155
# ECLI-NL-RBBRE-2005-AS5631
# ECLI-NL-RBROT-2023-48
# ECLI-NL-RBDHA-2022-7425
# ECLI-NL-RBDHA-2021-3759
# ECLI-NL-RBNNE-2014-6188
# ECLI-NL-RBDHA-2022-14059
# ECLI-NL-RBMNE-2016-7751
# ECLI-NL-RBMNE-2022-840
# ECLI-NL-RBDHA-2017-6513
# ECLI-NL-RBARN-2010-BM4036
# ECLI-NL-RBZUT-2007-BB4501
# ECLI-NL-GHAMS-2011-BQ8112
# ECLI-NL-GHSHE-2011-BQ4388
# ECLI-NL-GHDHA-2018-954
# ECLI-NL-OGHNAA-2008-BH0939
# ECLI-NL-RBHAA-2008-BC9447
# ECLI-NL-RBZUT-2007-AZ7318
# ECLI-NL-OGEAA-2021-367
# ECLI-NL-GHAMS-2018-4050
# ECLI-NL-RBROT-2021-1367
# ECLI-NL-RBAMS-2020-5070
# ECLI-NL-RBHAA-2009-BH3433
# ECLI-NL-RBGRO-2011-BR4370
# ECLI-NL-GHARL-2022-7936
# ECLI-NL-RBZUT-2007-BB4499
# ECLI-NL-GHDHA-2016-1868
# ECLI-NL-GHAMS-2019-3280
# ECLI-NL-RBROT-2017-10368
# ECLI-NL-RBALK-2010-BO7285
# ECLI-NL-RBZUT-2007-AZ7239
# ECLI-NL-GHAMS-2017-833
# ECLI-NL-RBMNE-2020-4161
# ECLI-NL-GHAMS-2021-3214
# ECLI-NL-RBROT-2021-2696
# ECLI-NL-RBAMS-2022-4825
# ECLI-NL-RBSHE-2005-AU3189
# ECLI-NL-GHAMS-2019-4887
# ECLI-NL-RBZUT-2008-BC3665
# ECLI-NL-GHDHA-2021-1065
# ECLI-NL-RBALK-2006-AZ5733
# ECLI-NL-RBGRO-2010-BN8758
# ECLI-NL-GHSHE-2015-1480
# ECLI-NL-RBZUT-2007-BB4493
# ECLI-NL-OGHNAA-2009-BI1705
# ECLI-NL-RBUTR-2012-BY6121
# ECLI-NL-RBMNE-2022-4093
# ECLI-NL-RBMNE-2022-2688
# ECLI-NL-GHARL-2020-5328
# ECLI-NL-RBZWB-2019-5619
# ECLI-NL-RBLIM-2017-6714
# ECLI-NL-RBLIM-2017-6740
# ECLI-NL-RBNNE-2015-1095
# ECLI-NL-RBOBR-2017-4876
# ECLI-NL-RBAMS-2020-6285
# ECLI-NL-RBNNE-2019-2206
# ECLI-NL-RBNNE-2019-2208
# ECLI-NL-RBASS-2007-BA1099
# ECLI-NL-RBZWB-2021-2248
# ECLI-NL-RBAMS-2004-AQ6064
# ECLI-NL-RBROT-2018-1076
# ECLI-NL-RBUTR-2010-BN8132
# ECLI-NL-RBUTR-2012-BW9481
# ECLI-NL-GHARL-2019-6152
# ECLI-NL-RBNNE-2021-4620
# ECLI-NL-RBSHE-2005-AU3186
# ECLI-NL-RBDHA-2017-6512
# ECLI-NL-RBUTR-2010-BN6251
# ECLI-NL-RBNNE-2020-1286
# ECLI-NL-RBROT-2019-6554
# ECLI-NL-RBMNE-2020-539
# ECLI-NL-RBUTR-2007-BC0846
# ECLI-NL-CRVB-2005-AU7662
# ECLI-NL-RBZWB-2017-418
# ECLI-NL-GHAMS-2019-1760
# ECLI-NL-RBZUT-2007-BB4495
# ECLI-NL-RBAMS-2019-5305
# ECLI-NL-RBALK-2006-AZ5740
# ECLI-NL-RBROT-2019-6968
# ECLI-NL-RBAMS-2020-4515
# ECLI-NL-RBAMS-2020-6077
# ECLI-NL-RBZUT-2007-AZ7312
# ECLI-NL-GHAMS-2006-AY3763
# ECLI-NL-RBGEL-2013-4806
# ECLI-NL-GHARL-2021-793
# ECLI-NL-RBAMS-2020-1220
# ECLI-NL-RBNNE-2018-4809
# ECLI-NL-RBNNE-2014-5275
# ECLI-NL-GHAMS-2020-2458
# ECLI-NL-RBAMS-2019-5302
# ECLI-NL-RBAMS-2017-3314
# ECLI-NL-RBNNE-2019-170
# ECLI-NL-RBMNE-2017-93
# ECLI-NL-RBUTR-2011-BV6324
# ECLI-NL-RBAMS-2020-4513
# ECLI-NL-GHAMS-2016-5289
# ECLI-NL-RBZWB-2019-2735
# ECLI-NL-RBBRE-2008-BC8920
# ECLI-NL-RBNNE-2017-5051
# ECLI-NL-RBMNE-2016-7752
# ECLI-NL-RBROT-2015-8051
# ECLI-NL-RBUTR-2009-BH5197
# ECLI-NL-RBZUT-2008-BC3669
# ECLI-NL-RBOVE-2021-4829
# ECLI-NL-RBMNE-2014-765
# ECLI-NL-RBROT-2021-3224
# ECLI-NL-RBAMS-2021-7958
# ECLI-NL-OGEAA-2021-416
# ECLI-NL-RBROT-2020-12526
# ECLI-NL-GHAMS-2019-4675
# ECLI-NL-RBROT-2017-10367
# ECLI-NL-RBHAA-2007-BA9035
# ECLI-NL-RBOBR-2016-2222
# ECLI-NL-GHAMS-2003-AN8910
# ECLI-NL-RBUTR-2011-BV6677
# ECLI-NL-RBAMS-2021-6049
# ECLI-NL-RBAMS-2020-4519
# ECLI-NL-RBARN-2012-BW5855
# ECLI-NL-RBGRO-2012-BX2335
# ECLI-NL-RBOVE-2018-1896
# ECLI-NL-GHARL-2018-10739
# ECLI-NL-RBZUT-2004-AO5695
# ECLI-NL-RBOVE-2020-2814
# ECLI-NL-RBOVE-2020-2815
# ECLI-NL-RBOVE-2020-2816
# ECLI-NL-RBROT-2018-5204
# ECLI-NL-GHSHE-2016-4487
# ECLI-NL-GHSHE-2012-BW7042
# ECLI-NL-RBMNE-2022-841
# ECLI-NL-RBOVE-2020-1918
# ECLI-NL-RBOVE-2020-1590
# ECLI-NL-RBMNE-2014-4790
# ECLI-NL-RBARN-2011-BP1481
# ECLI-NL-RBAMS-2017-3327
# ECLI-NL-RBBRE-2008-BC8934
# ECLI-NL-RBGEL-2018-5193
# ECLI-NL-GHAMS-2018-4604
# ECLI-NL-RBROT-2017-10353
# ECLI-NL-RBALM-2008-BG6327
# ECLI-NL-RBAMS-2019-448
# ECLI-NL-GHAMS-2018-4296
# ECLI-NL-RBROT-2017-8988
# ECLI-NL-RBOBR-2016-4868
# ECLI-NL-GHAMS-2020-1083
# ECLI-NL-RBNNE-2020-576
# ECLI-NL-RBZWB-2022-8352
# ECLI-NL-RBAMS-2022-3676
# ECLI-NL-GHAMS-2021-4285
# ECLI-NL-RBNHO-2022-997
# ECLI-NL-GHAMS-2020-2935
# ECLI-NL-RBROT-2017-4288
# ECLI-NL-RBZWB-2021-1836
# ECLI-NL-RBROT-2017-4477
# ECLI-NL-RBAMS-2014-2173
# ECLI-NL-RBAMS-2004-AQ6507
# ECLI-NL-RBAMS-2004-AQ6509
# ECLI-NL-RBNHO-2022-6622
# ECLI-NL-RBUTR-2012-7086
# ECLI-NL-RBOVE-2018-2193
# ECLI-NL-RBUTR-2011-BV5132
# ECLI-NL-RBROT-2020-9680
# ECLI-NL-RBDHA-2020-10752
# ECLI-NL-RBMNE-2022-2142
# ECLI-NL-GHAMS-2021-43
# ECLI-NL-RBZWB-2021-1625
# ECLI-NL-RBMNE-2021-4712
# ECLI-NL-GHSHE-2004-AO9591
# ECLI-NL-RBOBR-2016-463
# ECLI-NL-RBROT-2022-1386
# ECLI-NL-RBZWB-2018-4618
# ECLI-NL-RBMAA-2011-BP1648
# ECLI-NL-RBMNE-2021-2435
# ECLI-NL-GHLEE-2010-BL6688
# ECLI-NL-RBDHA-2022-6757
# ECLI-NL-RBDHA-2022-6766
# ECLI-NL-RBMAA-2012-BX5663
# ECLI-NL-RBSHE-2012-BW8502
# ECLI-NL-RBALM-2005-AS5259
# ECLI-NL-RBNHO-2020-4762
# ECLI-NL-RBAMS-2022-3675
# ECLI-NL-GHAMS-2019-207
# ECLI-NL-RBLIM-2021-8794
# ECLI-NL-RBUTR-2009-BH5087
# ECLI-NL-RBROT-2021-2695
# ECLI-NL-RBAMS-2022-4073
# ECLI-NL-RBAMS-2019-5303
# ECLI-NL-RBSHE-2005-AT6530
# ECLI-NL-RBZWB-2021-1830
# ECLI-NL-RBNNE-2019-5248
# ECLI-NL-RBLIM-2022-9569
# ECLI-NL-RBGEL-2021-7077
# ECLI-NL-RBMAA-2006-AV6300
# ECLI-NL-RBROT-2021-9227
# ECLI-NL-RBARN-2012-BW9811
# ECLI-NL-RBMAA-2007-AZ8020
# ECLI-NL-RBGEL-2018-129
# ECLI-NL-GHSHE-2004-AR8282
# ECLI-NL-RBOVE-2021-1520
# ECLI-NL-RBUTR-2012-7102
# ECLI-NL-OGHNAA-2010-BM7498
# ECLI-NL-RBBRE-2010-BN2847
# ECLI-NL-RBNNE-2021-1511
# ECLI-NL-GHAMS-2014-4180
# ECLI-NL-GHDHA-2015-3653
# ECLI-NL-RBZWB-2021-1842
# ECLI-NL-RBGEL-2022-7330
# ECLI-NL-RBOVE-2018-1900
# ECLI-NL-GHSHE-2009-BH2779
# ECLI-NL-RBROT-2017-8990
# ECLI-NL-GHSHE-2018-903
# ECLI-NL-RBMNE-2020-3270
# ECLI-NL-RBGEL-2021-7083
# ECLI-NL-RBBRE-2010-BN2132
# ECLI-NL-RBNNE-2017-1462
# ECLI-NL-GHAMS-2022-2679
# ECLI-NL-RBAMS-2018-10000
# ECLI-NL-OGEAC-2015-17
# ECLI-NL-RBAMS-2019-5299
# ECLI-NL-RBZUT-2009-BH2861
# ECLI-NL-RBAMS-2012-BW0708
# ECLI-NL-RBROT-2020-9796
# ECLI-NL-GHSHE-2013-2745
# ECLI-NL-RBMNE-2022-4789
# ECLI-NL-RBMNE-2014-1630
# ECLI-NL-RBMNE-2016-7753
# ECLI-NL-GHAMS-2014-4240
# ECLI-NL-GHAMS-2011-BQ8090
# ECLI-NL-RBNNE-2014-5484
# ECLI-NL-RBOVE-2021-2617
# ECLI-NL-RBUTR-2005-BP8667
# ECLI-NL-OGEAA-2016-733
# ECLI-NL-RBZWB-2022-1523
# ECLI-NL-RBROT-2019-5966
# ECLI-NL-GHARN-2010-BM2638
# ECLI-NL-GHAMS-2021-1448
# ECLI-NL-RBMNE-2022-1545
# ECLI-NL-RBAMS-2020-6076
# ECLI-NL-RBOBR-2017-3064
# ECLI-NL-RBALM-2008-BD2923
# ECLI-NL-RBROT-2017-10887
# ECLI-NL-RBGEL-2021-5847
# ECLI-NL-RBOBR-2018-3071
# ECLI-NL-RBALM-2008-BD9840
# ECLI-NL-RBDHA-2020-9299
# ECLI-NL-RBGEL-2018-546
# ECLI-NL-RBGRO-2006-AY9342
# ECLI-NL-RBNHO-2021-12644
# ECLI-NL-RBROT-2020-711
# ECLI-NL-RBROT-2020-12542
# ECLI-NL-RBUTR-2011-BP3119
# ECLI-NL-RBALK-2009-BJ4697
# ECLI-NL-RBARN-2011-BP1496
# ECLI-NL-RBAMS-2017-4878
# ECLI-NL-RBZUT-2011-BR4383
# ECLI-NL-GHARN-2012-BX4207
# ECLI-NL-GHAMS-2021-2186
# ECLI-NL-RBAMS-2022-4069
# ECLI-NL-RBDHA-2022-6763
# ECLI-NL-RBDHA-2022-6774
# ECLI-NL-RBDHA-2022-6764
# ECLI-NL-RBOBR-2021-4717
# ECLI-NL-GHSHE-2014-4594
# ECLI-NL-CRVB-2010-BL6372
# ECLI-NL-RBUTR-2009-BJ2151
# ECLI-NL-RBGRO-2009-BI0985
# ECLI-NL-RBASS-2006-AY9315
# ECLI-NL-RBASS-2006-AX6832
# ECLI-NL-RVS-2006-AX4387
# ECLI-NL-RBAMS-2020-6075
# ECLI-NL-RBDHA-2020-6767
# ECLI-NL-RBMAA-2009-BK7905
# ECLI-NL-RBNHO-2020-10314
# ECLI-NL-RBNNE-2015-3618
# ECLI-NL-RBAMS-2020-5071
# ECLI-NL-RBNHO-2013-10220
# ECLI-NL-RBMNE-2021-4932
# ECLI-NL-RBLIM-2022-7127
# ECLI-NL-RBMNE-2016-548
# ECLI-NL-GHARL-2020-10369
# ECLI-NL-RBAMS-2021-6892
# ECLI-NL-RBMNE-2022-236
# ECLI-NL-RBROT-2017-8993
# ECLI-NL-RBOBR-2017-2116
# ECLI-NL-GHARN-2012-BX9389
# ECLI-NL-RBZWB-2022-1514
# ECLI-NL-RBNNE-2019-3019
# ECLI-NL-RBNNE-2022-419
# ECLI-NL-RBNHO-2022-5046
# ECLI-NL-RBAMS-2020-1855
# ECLI-NL-RBMNE-2021-3723
# ECLI-NL-RBGEL-2022-216
# ECLI-NL-RBHAA-2012-BY5942
# ECLI-NL-RBAMS-2017-6279
# ECLI-NL-RBAMS-2019-5301
# ECLI-NL-RBGEL-2018-5194
# ECLI-NL-RBALK-2008-BC8333
# ECLI-NL-RBOBR-2013-BZ9633
# ECLI-NL-RBALK-2009-BJ4693
# ECLI-NL-GHAMS-2018-1968
# ECLI-NL-RBROT-2021-7765
# ECLI-NL-RBROT-2018-4599
# ECLI-NL-RBROT-2020-5447
# ECLI-NL-GHARL-2020-7391
# ECLI-NL-RBAMS-2021-6894
# ECLI-NL-RBGEL-2016-6445
# ECLI-NL-RBOBR-2021-5049
# ECLI-NL-RBMNE-2020-3948
# ECLI-NL-GHARL-2019-10668
# ECLI-NL-RBAMS-2021-1598
# ECLI-NL-RBNNE-2021-3945
# ECLI-NL-RBROT-2022-7839
# ECLI-NL-RBAMS-2020-1854
# ECLI-NL-RBAMS-2018-8939
# ECLI-NL-RBAMS-2021-6965
# ECLI-NL-RBDHA-2020-10757
# ECLI-NL-RBMNE-2016-550
# ECLI-NL-RBZWB-2019-2797
# ECLI-NL-RBAMS-2016-3604
# ECLI-NL-PHR-2018-641
# ECLI-NL-RBMNE-2014-3911
# ECLI-NL-GHAMS-2020-2803
# ECLI-NL-RBUTR-2011-BQ9069
# ECLI-NL-RBGEL-2021-4908
# ECLI-NL-RBLIM-2015-4951
# ECLI-NL-RBROT-2020-5429
# ECLI-NL-RBARN-2012-BV6403
# ECLI-NL-RBNNE-2022-464
# ECLI-NL-GHAMS-2022-1494
# ECLI-NL-RBDHA-2020-11854
# ECLI-NL-RBMNE-2021-130
# ECLI-NL-RBARN-2012-BW1082
# ECLI-NL-RBHAA-2008-BF1047
# ECLI-NL-GHAMS-2021-42
# ECLI-NL-GHARL-2022-2809
# ECLI-NL-GHAMS-2015-4577
# ECLI-NL-GHAMS-2021-2183
# ECLI-NL-RBZWB-2021-1400
# ECLI-NL-RBROT-2021-9633
# ECLI-NL-RBLIM-2018-10170
# ECLI-NL-RBARN-2010-BO1991
# ECLI-NL-RBUTR-2007-BC2180
# ECLI-NL-RBOBR-2019-3083
# ECLI-NL-RBOVE-2021-4835
# ECLI-NL-RBMNE-2015-5797
# ECLI-NL-RBNNE-2015-5816
# ECLI-NL-RBMNE-2016-547
# ECLI-NL-RBHAA-2007-BA4933
# ECLI-NL-RBZUT-2009-BH2859
# ECLI-NL-GHAMS-2020-3066
# ECLI-NL-RBSHE-2005-AU3182
# ECLI-NL-RBOBR-2014-3478
# ECLI-NL-RBMNE-2021-6237
# ECLI-NL-RVS-2022-285
# ECLI-NL-RBOVE-2015-5331
# ECLI-NL-GHAMS-2020-1930
# ECLI-NL-RBOBR-2019-7097
# ECLI-NL-GHSHE-2015-29
# ECLI-NL-RBMNE-2021-6164
# ECLI-NL-RBROT-2018-5202
# ECLI-NL-RBAMS-2017-9583
# ECLI-NL-RBOVE-2022-26
# ECLI-NL-RBLIM-2018-3520
# ECLI-NL-RBNNE-2017-4941
# ECLI-NL-RBGEL-2016-513
# ECLI-NL-RBZWB-2022-7386
# ECLI-NL-RBROT-2017-9499
# ECLI-NL-RBROT-2013-CA1232
# ECLI-NL-RBROT-2021-1543
# ECLI-NL-RBMNE-2016-551
# ECLI-NL-RBLIM-2017-1458
# ECLI-NL-RBOBR-2018-3042
# ECLI-NL-GHAMS-2021-960
# ECLI-NL-RBZUT-2010-BN5611
# ECLI-NL-RBZUT-2010-BO7302
# ECLI-NL-GHAMS-2022-2020
# ECLI-NL-RBUTR-2011-BV5127
# ECLI-NL-GHAMS-2019-5125
# ECLI-NL-RBZWB-2022-2779
# ECLI-NL-RBNNE-2022-420
# ECLI-NL-RBOVE-2021-547
# ECLI-NL-RBZWB-2022-2617
# ECLI-NL-RBOBR-2014-6477
# ECLI-NL-CRVB-2022-2025
# ECLI-NL-RBGEL-2020-5983
# ECLI-NL-RBMNE-2022-5655
# ECLI-NL-GHARL-2022-997
# ECLI-NL-GHSHE-2009-BH0715
# ECLI-NL-RBOVE-2021-2537
# ECLI-NL-GHAMS-2016-1765
# ECLI-NL-GHAMS-2021-3549
# ECLI-NL-RBROE-2012-BV2738
# ECLI-NL-RBGEL-2019-4464
# ECLI-NL-RBLIM-2019-3270
# ECLI-NL-PHR-2003-AM2764
# ECLI-NL-RBZUT-2009-BI3868
# ECLI-NL-RBROT-2016-7329
# ECLI-NL-RBMNE-2016-549
# ECLI-NL-RBGEL-2021-5595
# ECLI-NL-RBROT-2021-10941
# ECLI-NL-PHR-2016-648
# ECLI-NL-RBAMS-2021-3580
# ECLI-NL-RBLIM-2013-12370
# ECLI-NL-RBOVE-2022-2687
# ECLI-NL-RBOVE-2019-468
# ECLI-NL-RBZWB-2017-3847
# ECLI-NL-GHLEE-2010-BM1732
# ECLI-NL-GHSHE-2009-BJ9372
# ECLI-NL-RBROT-2018-3042
# ECLI-NL-GHAMS-2022-3749
# ECLI-NL-GHSHE-2009-BH0704
# ECLI-NL-RBGRO-2010-BN2471
# ECLI-NL-RBNHO-2019-10200
# ECLI-NL-RBLIM-2022-5233
# ECLI-NL-GHSHE-2009-BI4026
# ECLI-NL-RBZWB-2019-2458
# ECLI-NL-RBMNE-2022-2900
# ECLI-NL-RBNNE-2020-3934
# ECLI-NL-RBSHE-2012-BW8629
# ECLI-NL-RBOVE-2019-2668
# ECLI-NL-RBDHA-2021-6361
# ECLI-NL-RBZUT-2008-BD0696
# ECLI-NL-RBOVE-2022-800
# ECLI-NL-OGEAC-2015-9
# ECLI-NL-RBMNE-2013-8001
# ECLI-NL-GHLEE-2009-BJ4251
# ECLI-NL-RBAMS-2022-7082
# ECLI-NL-RBAMS-2018-8938
# ECLI-NL-GHSHE-2002-AE9298
# ECLI-NL-GHSHE-2022-635
# ECLI-NL-RBGEL-2021-5876
# ECLI-NL-RBGEL-2020-6662
# ECLI-NL-RBAMS-2019-5551
# ECLI-NL-RBALK-2007-AZ5499
# ECLI-NL-CRVB-2010-BL0860
# ECLI-NL-GHAMS-2018-4603
# ECLI-NL-RBNNE-2020-1281
# ECLI-NL-RBOVE-2021-3410
# ECLI-NL-RBAMS-2021-855
# ECLI-NL-RBDHA-2019-14032
# ECLI-NL-RBNNE-2018-5197
# ECLI-NL-RBROT-2018-5205
# ECLI-NL-RBZWB-2022-6217
# ECLI-NL-GHSHE-2021-2027
# ECLI-NL-RBARN-2010-BM4209
# ECLI-NL-RBAMS-2017-3256
# ECLI-NL-RBROT-2021-3927
# ECLI-NL-RBROT-2019-5150
# ECLI-NL-GHAMS-2021-4456
# ECLI-NL-RBLIM-2013-12378
# ECLI-NL-GHAMS-2020-3172
# ECLI-NL-RBNNE-2017-2760
# ECLI-NL-RBNNE-2022-450
# ECLI-NL-RBROT-2018-5203
# ECLI-NL-RBAMS-2018-4698
# ECLI-NL-RBZWB-2021-1088
# ECLI-NL-OGHACMB-2010-BP2889
# ECLI-NL-RBOBR-2016-3274
# ECLI-NL-RBUTR-2008-BD9485
# ECLI-NL-GHAMS-2019-1152
# ECLI-NL-RBALM-2012-BV8931
# ECLI-NL-GHAMS-2020-1874
# ECLI-NL-RBDHA-2022-6769
# ECLI-NL-RBDHA-2022-6765
# ECLI-NL-GHARL-2017-11401
# ECLI-NL-GHSHE-2016-2326
# ECLI-NL-RBAMS-2014-7415
# ECLI-NL-GHSHE-2012-BV9125
# ECLI-NL-RBROE-2009-BJ5137
# ECLI-NL-RBHAA-2005-AS5774
# ECLI-NL-GHSHE-2021-3041
# ECLI-NL-RBROT-2018-1075
# ECLI-NL-RBOVE-2021-1699
# ECLI-NL-RBROT-2022-5428
# ECLI-NL-RBDHA-2023-230
# ECLI-NL-RBMID-2003-AN8449
# ECLI-NL-RBMNE-2019-3150
# ECLI-NL-RBAMS-2021-2238
# ECLI-NL-RBNNE-2021-1907
# ECLI-NL-RBROT-2020-12689
# ECLI-NL-GHAMS-2002-AE7044
# ECLI-NL-RBAMS-2017-4121
# ECLI-NL-RBUTR-2011-BV5150
# ECLI-NL-RBNNE-2019-780
# ECLI-NL-RBZUT-2007-AZ7254
# ECLI-NL-GHARL-2022-5822
# ECLI-NL-CRVB-2021-3343
# ECLI-NL-RBMNE-2013-BZ6238
# ECLI-NL-RBROT-2019-8168
# ECLI-NL-RBNNE-2018-2703
# ECLI-NL-RBAMS-2022-3432
# ECLI-NL-RBSGR-2009-BL0538
# ECLI-NL-GHARL-2018-8529
# ECLI-NL-RBLIM-2021-7302
# ECLI-NL-RBOBR-2018-1914
# ECLI-NL-RBUTR-2009-BK3195
# ECLI-NL-RBAMS-2019-8571
# ECLI-NL-RBLIM-2013-11777
# ECLI-NL-GHARN-2010-BM7156
# ECLI-NL-RBOVE-2019-3687
# ECLI-NL-RBOBR-2021-5217
# ECLI-NL-RBROT-2022-11426
# ECLI-NL-RBGRO-2007-BA4380
# ECLI-NL-RBROT-2019-5294
# ECLI-NL-RBNNE-2019-195
# ECLI-NL-RBGEL-2021-2126
# ECLI-NL-RBAMS-2022-4071
# ECLI-NL-RBOVE-2018-3959
# ECLI-NL-RBOBR-2022-3967
# ECLI-NL-RBNNE-2022-3766
# ECLI-NL-RBZUT-2007-AZ7229
# ECLI-NL-RBMNE-2022-2527
# ECLI-NL-GHARL-2022-6140
# ECLI-NL-RBUTR-2007-BB8317
# ECLI-NL-CRVB-2018-4141
# ECLI-NL-GHDHA-2020-1314
# ECLI-NL-RBLIM-2015-7791
# ECLI-NL-RBOVE-2015-268
# ECLI-NL-RBOBR-2022-92
# ECLI-NL-RBROT-2018-3043
# ECLI-NL-RBDHA-2019-9760
# ECLI-NL-GHAMS-2021-161
# ECLI-NL-RBLIM-2021-379
# ECLI-NL-RBLIM-2017-12743
# ECLI-NL-RBDHA-2021-3368
# ECLI-NL-GHSHE-2009-BH0705
# ECLI-NL-RBMNE-2013-BZ3561
# ECLI-NL-RBNNE-2022-1211
# ECLI-NL-RBOVE-2018-257
# ECLI-NL-RBGEL-2016-6494
# ECLI-NL-GHSHE-2019-4875
# ECLI-NL-RBALK-2006-AZ0880
# ECLI-NL-RBGEL-2016-6495
# ECLI-NL-RBAMS-2019-7801
# ECLI-NL-RBROT-2019-5292
# ECLI-NL-RBARN-2012-BY2370
# ECLI-NL-OGHACMB-2013-CA0522
# ECLI-NL-RBOBR-2014-5437
# ECLI-NL-RBALK-2011-BR1616
# ECLI-NL-RBGEL-2018-131
# ECLI-NL-PHR-2020-903
# ECLI-NL-RBOBR-2020-4538
# ECLI-NL-RBROT-2021-1491
# ECLI-NL-RBAMS-2022-1288
# ECLI-NL-RBGEL-2016-6468
# ECLI-NL-RBUTR-2012-7101
# ECLI-NL-GHAMS-2019-1154
# ECLI-NL-RBGEL-2021-267
# ECLI-NL-RBZWB-2020-1121
# ECLI-NL-RBUTR-2007-BA5382
# ECLI-NL-RBUTR-2009-BI1945
# ECLI-NL-RBROT-2018-11309
# ECLI-NL-GHARL-2021-9411
# ECLI-NL-GHSHE-2004-AO5359
# ECLI-NL-RBUTR-2011-BQ9055
# ECLI-NL-RBOVE-2019-2676
# ECLI-NL-RBGRO-2011-BR4376
# ECLI-NL-RBZWB-2017-3871
# ECLI-NL-RBARN-2010-BO2061
# ECLI-NL-RBLIM-2020-4855
# ECLI-NL-RBROT-2018-3044
# ECLI-NL-RBROT-2021-1539
# ECLI-NL-RBOVE-2019-469
# ECLI-NL-RBAMS-2019-7799
# ECLI-NL-RBAMS-2019-8569
# ECLI-NL-RBARN-2011-BU7422
# ECLI-NL-GHSHE-2002-AE0062
# ECLI-NL-GHARL-2021-794
# ECLI-NL-RBZWB-2021-3404
# ECLI-NL-RBZWB-2021-3403
# ECLI-NL-RBOBR-2021-1704
# ECLI-NL-RBOVE-2021-2471
# ECLI-NL-GHDHA-2015-628
# ECLI-NL-RBROT-2020-11148
# ECLI-NL-RBMNE-2015-1141
# ECLI-NL-RBOBR-2016-536
# ECLI-NL-GHARN-2006-AY5412
# ECLI-NL-RBSHE-2005-AU3183
# ECLI-NL-RBARN-2010-BO2047
# ECLI-NL-RBGEL-2022-6667
# ECLI-NL-GHSHE-2019-4865
# ECLI-NL-GHARL-2020-10365
# ECLI-NL-RBUTR-2007-BC0843
# ECLI-NL-GHSHE-2019-4867
# ECLI-NL-RBGEL-2019-951
# ECLI-NL-RBOBR-2017-3709
# ECLI-NL-GHAMS-2021-3602
# ECLI-NL-OGEAC-2014-12
# ECLI-NL-GHAMS-2011-BR4724
# ECLI-NL-RBNNE-2019-4091
# ECLI-NL-RBOVE-2019-1835
# ECLI-NL-GHAMS-2020-3840
# ECLI-NL-RBUTR-2005-BP8641
# ECLI-NL-RBROT-2021-7303
# ECLI-NL-RBALM-2008-BD9839
# ECLI-NL-RBDHA-2015-10601
# ECLI-NL-RBARN-2010-BL0910
# ECLI-NL-GHAMS-2022-1665
# ECLI-NL-RBNHO-2013-13002
# ECLI-NL-RBARN-2010-BM4204
# ECLI-NL-RBZWB-2022-3249
# ECLI-NL-RBROT-2018-3784
# ECLI-NL-GHAMS-2022-189
# ECLI-NL-RBGEL-2015-2793
# ECLI-NL-RBLIM-2013-12372
# ECLI-NL-RBGRO-2010-BN8743
# ECLI-NL-RBOBR-2022-1699
# ECLI-NL-RBOVE-2020-2626
# ECLI-NL-RBLIM-2021-382
# ECLI-NL-RBZWB-2022-674
# ECLI-NL-RBZWB-2022-3250
# ECLI-NL-GHAMS-2019-1751
# ECLI-NL-RBROT-2019-4815
# ECLI-NL-RBNHO-2014-7947
# ECLI-NL-GHSGR-2003-AN7586
# ECLI-NL-RBZUT-2010-BN9299
# ECLI-NL-RBUTR-2009-BK4671
# ECLI-NL-RBUTR-2008-BD7405
# ECLI-NL-RBAMS-2010-BL1028
# ECLI-NL-GHAMS-2020-3695
# ECLI-NL-RBLIM-2021-378
# ECLI-NL-GHSHE-2019-4869
# ECLI-NL-RBARN-2010-BM7959
# ECLI-NL-RBALK-2011-BU6576
# ECLI-NL-GHSHE-2013-BZ5454
# ECLI-NL-RBNNE-2021-298
# ECLI-NL-RBALM-2008-BD0053
# ECLI-NL-RBHAA-2006-AZ2894
# ECLI-NL-GHSHE-2019-4874
# ECLI-NL-RBOVE-2016-4373
# ECLI-NL-GHAMS-2019-2823
# ECLI-NL-RBSGR-2008-BD7012
# ECLI-NL-GHAMS-2021-2726
# ECLI-NL-RBOVE-2019-1457
# ECLI-NL-GHAMS-2022-2283
# ECLI-NL-RBOBR-2021-1707
# ECLI-NL-GHARL-2021-864
# ECLI-NL-RBNNE-2013-2800
# ECLI-NL-RBOBR-2015-7659
# ECLI-NL-RBAMS-2022-8194
# ECLI-NL-RBDHA-2021-14537
# ECLI-NL-RBUTR-2007-BC0848
# ECLI-NL-RBNHO-2021-12183
# ECLI-NL-RBMNE-2021-2417
# ECLI-NL-RBLIM-2017-12784
# ECLI-NL-RBAMS-2012-BX0186
# ECLI-NL-GHSHE-2003-AP0606
# ECLI-NL-OGEAM-2022-64
# ECLI-NL-RBZWB-2021-1682
# ECLI-NL-RBROT-2020-12690
# ECLI-NL-RBMNE-2020-537
# ECLI-NL-RBOBR-2017-2117
# ECLI-NL-RBMNE-2017-1995
# ECLI-NL-RBOVE-2019-560
# ECLI-NL-RBUTR-2009-BK1429
# ECLI-NL-RBUTR-2009-BK1499
# ECLI-NL-RBUTR-2009-BK1522
# ECLI-NL-RBUTR-2009-BK1686
# ECLI-NL-RBUTR-2009-BK1689
# ECLI-NL-RBUTR-2009-BK1569
# ECLI-NL-RBUTR-2009-BK1709
# ECLI-NL-RBNNE-2022-4522
# ECLI-NL-RBUTR-2011-BQ9040
# ECLI-NL-RBMNE-2017-5473
# ECLI-NL-RBNNE-2019-2072
# ECLI-NL-RBUTR-2007-BC0847
# ECLI-NL-GHSGR-2005-AS5770
# ECLI-NL-RBGEL-2016-3349
# ECLI-NL-GHLEE-2005-AU8945
# ECLI-NL-RBMNE-2021-1748
# ECLI-NL-GHARL-2020-10660
# ECLI-NL-RBNNE-2018-5011
# ECLI-NL-GHARL-2018-8706
# ECLI-NL-RBNNE-2015-5806
# ECLI-NL-GHARN-2011-BU1785
# ECLI-NL-RBROE-2010-BO4798
# ECLI-NL-RBMAA-2004-AO8720
# ECLI-NL-RBMID-2011-BQ1638
# ECLI-NL-RBOBR-2020-4540
# ECLI-NL-RBGEL-2022-5719
# ECLI-NL-GHAMS-2021-4150
# ECLI-NL-GHSHE-2003-AN9889
# ECLI-NL-RBNNE-2018-2623
# ECLI-NL-RBROT-2017-5827
# ECLI-NL-GHSHE-2019-964
# ECLI-NL-GHSHE-2019-4873
# ECLI-NL-RBUTR-2007-BC1749
# ECLI-NL-RBAMS-2017-4117
# ECLI-NL-RBZWB-2019-6309
# ECLI-NL-RBUTR-2011-BV2681
# ECLI-NL-GHAMS-2019-1359
# ECLI-NL-GHDHA-2017-2321
# ECLI-NL-RBGEL-2016-6469
# ECLI-NL-RBAMS-2021-3012
# ECLI-NL-GHLEE-2010-BO8936
# ECLI-NL-RBDHA-2022-4060
# ECLI-NL-RBSGR-2010-BN5932
# ECLI-NL-RBLIM-2020-4409
# ECLI-NL-RBOBR-2018-18
# ECLI-NL-GHAMS-2018-4629
# ECLI-NL-RBLIM-2018-3476
# ECLI-NL-RBZWB-2019-5234
# ECLI-NL-RBLIM-2022-3230
# ECLI-NL-RBOVE-2020-4647
# ECLI-NL-RBARN-2010-BN1979
# ECLI-NL-RBALK-2008-BC7691
# ECLI-NL-RBZUT-2009-BI3857
# ECLI-NL-GHSGR-2010-BL0780
# ECLI-NL-RBGEL-2018-1951
# ECLI-NL-RBAMS-2022-6289
# ECLI-NL-RBROT-2020-8881
# ECLI-NL-RBMNE-2017-1990
# ECLI-NL-GHSHE-2015-1518
# ECLI-NL-RBMNE-2020-5646
# ECLI-NL-RBNNE-2018-353
# ECLI-NL-RBROT-2018-1964
# ECLI-NL-RBHAA-2011-BT1584
# ECLI-NL-RBGRO-2011-BR4374
# ECLI-NL-RBAMS-2019-9302
# ECLI-NL-RBALM-2012-BV8930
# ECLI-NL-RBAMS-2021-1005
# ECLI-NL-GHAMS-2018-4602
# ECLI-NL-RBGEL-2016-191
# ECLI-NL-RBZWB-2022-7121
# ECLI-NL-RBMNE-2020-4454
# ECLI-NL-PHR-2014-2264
# ECLI-NL-RBROT-2013-7277
# ECLI-NL-RBUTR-2010-BO8352
# ECLI-NL-RBUTR-2011-BV6674
# ECLI-NL-RBOVE-2021-606
# ECLI-NL-RBROT-2006-AZ8683
# ECLI-NL-RBMID-2003-AN8467
# ECLI-NL-RBNNE-2013-1432
# ECLI-NL-RBROT-2022-2171
# ECLI-NL-PHR-2021-788
# ECLI-NL-RBUTR-2011-BT1937
# ECLI-NL-RBZWB-2018-285
# ECLI-NL-OGEAC-2022-271
# ECLI-NL-RBGEL-2015-1759
# ECLI-NL-RBLIM-2017-11553
# ECLI-NL-GHAMS-2022-2281
# ECLI-NL-RBROT-2020-7079
# ECLI-NL-RBROT-2020-7501
# ECLI-NL-RBROT-2020-9256
# ECLI-NL-RBLIM-2017-12725
# ECLI-NL-RBNNE-2022-3412
# ECLI-NL-RBMAA-2012-BV1365
# ECLI-NL-RBNNE-2021-4622
# ECLI-NL-RBNNE-2022-836
# ECLI-NL-RBGEL-2022-1454
# ECLI-NL-RBARN-2010-BO3947
# ECLI-NL-RBDHA-2021-14766
# ECLI-NL-RBROT-2020-6159
# ECLI-NL-GHARL-2022-5151
# ECLI-NL-RBDHA-2022-8304
# ECLI-NL-RBNNE-2017-3508
# ECLI-NL-GHAMS-2022-1741
# ECLI-NL-GHDHA-2022-860
# ECLI-NL-GHAMS-2019-4991
# ECLI-NL-RBARN-2012-BX4520
# ECLI-NL-RBAMS-2019-8568
# ECLI-NL-GHAMS-2019-4215
# ECLI-NL-RBGEL-2018-5192
# ECLI-NL-GHSHE-2019-2366
# ECLI-NL-RBNNE-2019-1478
# ECLI-NL-RBGEL-2019-3587
# ECLI-NL-RBSHE-2012-BV9717
# ECLI-NL-RBAMS-2015-8941
# ECLI-NL-RBOBR-2014-7537
# ECLI-NL-RBOVE-2020-2229
# ECLI-NL-RBNNE-2016-2651
# ECLI-NL-CRVB-2014-4359
# ECLI-NL-GHARL-2018-7230
# ECLI-NL-RBASS-2012-BV6596
# ECLI-NL-GHARL-2020-4228
# ECLI-NL-RBDHA-2022-4369
# ECLI-NL-GHSHE-2003-AO9103
# ECLI-NL-GHDHA-2014-1540
# ECLI-NL-RBMNE-2019-1476
# ECLI-NL-RBNNE-2017-2999
# ECLI-NL-GHAMS-2019-3918
# ECLI-NL-RBNNE-2013-6924
# ECLI-NL-RBROT-2022-2174
# ECLI-NL-RBROT-2018-454
# ECLI-NL-RBZWB-2022-5490
# ECLI-NL-GHARL-2022-10569
# ECLI-NL-GHAMS-2010-BL8048
# ECLI-NL-RBAMS-2019-8572
# ECLI-NL-RBOBR-2014-5570
# ECLI-NL-RBROT-2018-4509
# ECLI-NL-RBGEL-2017-5634
# ECLI-NL-GHARL-2021-1534
# ECLI-NL-RBLIM-2021-2470
# ECLI-NL-PHR-2022-730
# ECLI-NL-RBAMS-2021-4049
# ECLI-NL-RBOBR-2017-1532
# ECLI-NL-CRVB-2004-AO7399
# ECLI-NL-RBAMS-2017-202
# ECLI-NL-RBBRE-2012-BV8562
# ECLI-NL-RBAMS-2021-6232
# ECLI-NL-GHSHE-2014-3308
# ECLI-NL-RBLIM-2017-12764
# ECLI-NL-RBZUT-2009-BI1168
# ECLI-NL-RBDOR-2006-AZ4923
# ECLI-NL-GHSHE-2011-BT8237
# ECLI-NL-RBASS-2009-BJ9605
# ECLI-NL-RBNNE-2022-329
# ECLI-NL-RBAMS-2017-4120
# ECLI-NL-RBAMS-2017-4122
# ECLI-NL-RBGEL-2015-7308
# ECLI-NL-GHARL-2022-8980
# ECLI-NL-RBOBR-2014-3476
# ECLI-NL-RBARN-2010-BN1957
# ECLI-NL-RBROT-2020-12039
# ECLI-NL-RBZWB-2021-1985
# ECLI-NL-RBOBR-2020-5574
# ECLI-NL-RBSHE-2012-BW0286
# ECLI-NL-RBUTR-2012-7099
# ECLI-NL-RBROT-2006-AZ8684
# ECLI-NL-RBOVE-2017-1729
# ECLI-NL-RBNHO-2016-1680
# ECLI-NL-RBNNE-2019-1043
# ECLI-NL-RBOVE-2021-2405
# ECLI-NL-OGEAC-2014-13
# ECLI-NL-GHAMS-2012-BV1102
# ECLI-NL-GHAMS-2014-2841
# ECLI-NL-RBMNE-2016-3959
# ECLI-NL-RBGEL-2014-4628
# ECLI-NL-RBZUT-2010-BN8797
# ECLI-NL-RBZWB-2019-2798
# ECLI-NL-RBLIM-2021-8949
# ECLI-NL-RBOVE-2019-1833
# ECLI-NL-RBAMS-2018-8685
# ECLI-NL-RBROT-2020-9679
# ECLI-NL-GHSHE-2017-256
# ECLI-NL-RBROT-2019-8415
# ECLI-NL-RBDHA-2021-3218
# ECLI-NL-RBHAA-2008-BC7284
# ECLI-NL-RBNNE-2013-BZ9457
# ECLI-NL-RBAMS-2017-4127
# ECLI-NL-GHARL-2021-10335
# ECLI-NL-GHSHE-2002-AE0075
# ECLI-NL-RBLIM-2021-5458
# ECLI-NL-RBLIM-2021-396
# ECLI-NL-RBDHA-2017-2512
# ECLI-NL-RBOVE-2019-712
# ECLI-NL-GHSHE-2006-AZ4219
# ECLI-NL-RBROT-2018-1074
# ECLI-NL-GHAMS-2020-3916
# ECLI-NL-GHSHE-2002-AF0970
# ECLI-NL-RBOBR-2018-1246
# ECLI-NL-RBOBR-2015-5149
# ECLI-NL-GHDHA-2014-327
# ECLI-NL-RBHAA-2007-AZ9416
# ECLI-NL-RBNNE-2015-3612
# ECLI-NL-RBOBR-2021-5048
# ECLI-NL-GHAMS-2022-2282
# ECLI-NL-RBMNE-2021-1744
# ECLI-NL-RBMNE-2021-1753
# ECLI-NL-RBZWB-2018-5113
# ECLI-NL-RBNNE-2018-2889
# ECLI-NL-RBNNE-2018-2883
# ECLI-NL-RBNNE-2018-2877
# ECLI-NL-RBNNE-2018-2909
# ECLI-NL-RBNNE-2018-2910
# ECLI-NL-RBNNE-2018-2908
# ECLI-NL-RBNNE-2018-2912
# ECLI-NL-RBNNE-2018-2935
# ECLI-NL-RBNNE-2018-2978
# ECLI-NL-RBNNE-2018-2972
# ECLI-NL-RBNNE-2018-2973
# ECLI-NL-RBNNE-2018-2974
# ECLI-NL-GHSHE-2014-1700
# ECLI-NL-GHSHE-2014-1698
# ECLI-NL-RBDHA-2014-1005
# ECLI-NL-RBNNE-2021-1808
# ECLI-NL-GHAMS-2019-3008
# ECLI-NL-RBUTR-2012-7103
# ECLI-NL-RBROT-2022-7530
# ECLI-NL-RBAMS-2022-6059
# ECLI-NL-RBAMS-2022-6060
# ECLI-NL-RBLIM-2019-8655
# ECLI-NL-GHSHE-2005-AT5298
# ECLI-NL-RBOVE-2013-BZ9340
# ECLI-NL-RBROT-2021-8079
# ECLI-NL-OGHNAA-2008-BG7885
# ECLI-NL-CRVB-2014-4369
# ECLI-NL-RBZUT-2012-BY7885
# ECLI-NL-RBDHA-2017-16469
# ECLI-NL-RBOVE-2013-3184
# ECLI-NL-RBROT-2022-7492
# ECLI-NL-RBHAA-2012-BW0082
# ECLI-NL-RBAMS-2017-8895
# ECLI-NL-RBROT-2017-10335
# ECLI-NL-GHARL-2015-8932
# ECLI-NL-RBNNE-2022-3496
# ECLI-NL-RBROT-2019-5339
# ECLI-NL-OGEAC-2020-187
# ECLI-NL-CRVB-2018-282
# ECLI-NL-RBMAA-2012-BV1366
# ECLI-NL-RBOVE-2021-3923
# ECLI-NL-RBOBR-2019-6377
# ECLI-NL-RBNNE-2022-145
# ECLI-NL-RBOVE-2022-1394
# ECLI-NL-RBOVE-2019-564
# ECLI-NL-CRVB-2019-2295
# ECLI-NL-RBMNE-2021-5478
# ECLI-NL-GHLEE-2009-BI2751
# ECLI-NL-RBMNE-2022-1492
# ECLI-NL-RBOVE-2020-2228
# ECLI-NL-RBROT-2021-10432
# ECLI-NL-RBNNE-2013-1430
# ECLI-NL-RBMNE-2015-1424
# ECLI-NL-RBGEL-2020-7067
# ECLI-NL-RBAMS-2022-5387
# ECLI-NL-RBGEL-2015-2313
# ECLI-NL-RBAMS-2022-6058
# ECLI-NL-GHAMS-2002-AE4509
# ECLI-NL-RBUTR-2010-BN0029
# ECLI-NL-RBHAA-2011-BQ4035
# ECLI-NL-RBNHO-2017-1940
# ECLI-NL-GHAMS-2022-115
# ECLI-NL-RBNNE-2013-2414
# ECLI-NL-RBOBR-2021-1705
# ECLI-NL-RBDHA-2022-5762
# ECLI-NL-GHAMS-2021-2208
# ECLI-NL-RBGEL-2018-5357
# ECLI-NL-RBOBR-2019-6373
# ECLI-NL-RBUTR-2011-BR3419
# ECLI-NL-RBAMS-2019-8570
# ECLI-NL-RBOVE-2022-358
# ECLI-NL-RBUTR-2005-BP8575
# ECLI-NL-RBZUT-2010-BN8792
# ECLI-NL-GHSHE-2019-4714
# ECLI-NL-RBGEL-2020-4891
# ECLI-NL-RBMNE-2022-1544
# ECLI-NL-RBROT-2021-3522
# ECLI-NL-RBOBR-2018-6481
# ECLI-NL-GHDHA-2016-474
# ECLI-NL-GHAMS-2021-3873
# ECLI-NL-RBMNE-2023-169
# ECLI-NL-RBHAA-2010-BM8069
# ECLI-NL-RBOBR-2022-4500
# ECLI-NL-GHARL-2020-5327
# ECLI-NL-RBUTR-2012-BW8558
# ECLI-NL-RBAMS-2022-2607
# ECLI-NL-RBROT-2020-6727
# ECLI-NL-RBZWB-2016-4215
# ECLI-NL-GHDHA-2020-705
# ECLI-NL-RBBRE-2006-AY7975
# ECLI-NL-RBNHO-2019-8257
# ECLI-NL-GHARL-2017-3937
# ECLI-NL-RBOVE-2019-2673
# ECLI-NL-RBDHA-2022-10784
# ECLI-NL-GHAMS-2021-3216
# ECLI-NL-OGHNAA-2009-BJ7631
# ECLI-NL-RBZWB-2018-4616
# ECLI-NL-RBDHA-2022-5445
# ECLI-NL-RBMNE-2020-4124
# ECLI-NL-GHSHE-2022-519
# ECLI-NL-RBALM-2007-AZ9814
# ECLI-NL-RBNNE-2021-2906
# ECLI-NL-RBROT-2017-10347
# ECLI-NL-RBDHA-2013-BZ8046
# ECLI-NL-RBNHO-2022-4994
# ECLI-NL-RBAMS-2018-7444
# ECLI-NL-RBMNE-2018-1884
# ECLI-NL-RBOBR-2021-4723
# ECLI-NL-RBOBR-2020-4350
# ECLI-NL-GHSHE-2017-5706
# ECLI-NL-RBMNE-2018-3903
# ECLI-NL-RBLIM-2022-3229
# ECLI-NL-RBOBR-2018-19
# ECLI-NL-RBZWB-2020-5246
# ECLI-NL-RBUTR-2007-BB8313
# ECLI-NL-HR-2003-AM2764
# ECLI-NL-RBUTR-2011-BU4844
# ECLI-NL-RBOVE-2021-1082
# ECLI-NL-RBMNE-2018-5099
# ECLI-NL-GHAMS-2021-1185
# ECLI-NL-RBSHE-2010-BL6000
# ECLI-NL-RBMNE-2022-2796
# ECLI-NL-GHSHE-2021-663
# ECLI-NL-RBLIM-2017-10225
# ECLI-NL-RBSGR-2005-AS6260
# ECLI-NL-RBOVE-2019-2665
# ECLI-NL-RBHAA-2012-CA1150
# ECLI-NL-RBOBR-2022-563
# ECLI-NL-RBSHE-2010-BN9965
# ECLI-NL-GHAMS-2003-AN9326
# ECLI-NL-RBNHO-2022-11583
# ECLI-NL-RBZWB-2015-6814
# ECLI-NL-RBOBR-2022-2234
# ECLI-NL-RBOBR-2016-5665
# ECLI-NL-RBROT-2022-2173
# ECLI-NL-RBMNE-2021-3965
# ECLI-NL-RBMNE-2018-1523
# ECLI-NL-RBMNE-2018-1524
# ECLI-NL-RBROT-2006-AX2482
# ECLI-NL-RBDHA-2022-12263
# ECLI-NL-RBNNE-2016-2507
# ECLI-NL-RBNNE-2014-5874
# ECLI-NL-RBNNE-2021-773
# ECLI-NL-RBROT-2014-3577
# ECLI-NL-RBGEL-2014-4627
# ECLI-NL-RBARN-2011-BU5626
# ECLI-NL-RBHAA-2011-BQ4425
# ECLI-NL-RBHAA-2008-BG7126
# ECLI-NL-RBMNE-2019-1172
# ECLI-NL-RBOVE-2021-1718
# ECLI-NL-RBGEL-2019-1714
# ECLI-NL-RBDHA-2022-7934
# ECLI-NL-RBROT-2019-3173
# ECLI-NL-GHLEE-2010-BN8169
# ECLI-NL-RBROT-2022-2172
# ECLI-NL-RBGEL-2019-6122
# ECLI-NL-RBMNE-2021-4379
# ECLI-NL-RBLIM-2021-1908
# ECLI-NL-RBOVE-2019-2701
# ECLI-NL-RBOBR-2021-5908
# ECLI-NL-RBNNE-2019-5226
# ECLI-NL-RBAMS-2019-629
# ECLI-NL-PHR-2005-AU3951
# ECLI-NL-RVS-2021-668
# ECLI-NL-RBROE-2010-BN0961
# ECLI-NL-RBHAA-2008-BC7431
# ECLI-NL-RBGEL-2019-1717
# ECLI-NL-RBDHA-2020-9996
# ECLI-NL-RVS-2020-1599
# ECLI-NL-RBZWB-2018-5125
# ECLI-NL-RBZWB-2018-5152
# ECLI-NL-GHSGR-2011-BT2475
# ECLI-NL-RBROT-2022-822
# ECLI-NL-RBZWB-2020-4206
# ECLI-NL-RBMNE-2017-5308
# ECLI-NL-RBROT-2020-8883
# ECLI-NL-RBZWB-2020-390
# ECLI-NL-GHAMS-2019-3862
# ECLI-NL-RBZWB-2022-7249
# ECLI-NL-GHAMS-2002-AE7040
# ECLI-NL-OGEAC-2018-244
# ECLI-NL-RBGEL-2022-5688
# ECLI-NL-RBOBR-2014-7700
# ECLI-NL-RBMNE-2020-653
# ECLI-NL-RBROT-2021-8748
# ECLI-NL-RBUTR-2008-BD1598
# ECLI-NL-GHARL-2016-7167
# ECLI-NL-RBROT-2019-5100
# ECLI-NL-GHARN-2009-BI7017
# ECLI-NL-RBDHA-2013-13470
# ECLI-NL-GHARL-2021-9974
# ECLI-NL-RBUTR-2011-BQ5687
# ECLI-NL-RBAMS-2022-15
# ECLI-NL-GHAMS-2020-2526
# ECLI-NL-RBLIM-2022-6417
# ECLI-NL-GHSHE-2021-3877
# ECLI-NL-RBMNE-2020-901
# ECLI-NL-RBMNE-2017-5217
# ECLI-NL-RBMNE-2017-5219
# ECLI-NL-RBHAA-2009-BK4962
# ECLI-NL-RBNNE-2018-3657
# ECLI-NL-RBOBR-2015-3124
# ECLI-NL-RBNHO-2017-1937
# ECLI-NL-RBGEL-2021-4753
# ECLI-NL-RBOVE-2018-3394
# ECLI-NL-GHAMS-2021-4077
# ECLI-NL-RBNHO-2022-7881
# ECLI-NL-RBOBR-2017-3711
# ECLI-NL-RBZWB-2021-2021
# ECLI-NL-RBROT-2017-4476
# ECLI-NL-RBOVE-2020-4643
# ECLI-NL-GHAMS-2018-4060
# ECLI-NL-RBZWB-2021-537
# ECLI-NL-RBNNE-2022-3409
# ECLI-NL-RBNNE-2016-2654
# ECLI-NL-RBNNE-2014-6128
# ECLI-NL-GHSHE-2012-BV6873
# ECLI-NL-GHARL-2020-4880
# ECLI-NL-GHAMS-2021-2717
# ECLI-NL-RBMNE-2016-3841
# ECLI-NL-RBROT-2013-5584
# ECLI-NL-RBGEL-2020-7074
# ECLI-NL-RBHAA-2012-BY8837
# ECLI-NL-RBMNE-2020-3947
# ECLI-NL-PHR-2013-BZ3622
# ECLI-NL-GHSHE-2021-732
# ECLI-NL-RBNNE-2019-3264
# ECLI-NL-RBASS-2006-AV1882
# ECLI-NL-GHSHE-2021-533
# ECLI-NL-RBHAA-2011-BU7631
# ECLI-NL-PHR-2005-AS3767
# ECLI-NL-GHAMS-2021-1644
# ECLI-NL-RBDHA-2022-1391
# ECLI-NL-RBMNE-2014-3310
# ECLI-NL-RBAMS-2015-8959
# ECLI-NL-RBAMS-2015-8960
# ECLI-NL-RBOBR-2022-2871
# ECLI-NL-GHSHE-2007-BB4256
# ECLI-NL-RBLIM-2018-3022
# ECLI-NL-RBNNE-2017-644
# ECLI-NL-RBNNE-2019-813
# ECLI-NL-RBOVE-2020-991
# ECLI-NL-RBASS-2008-BF9210
# ECLI-NL-RBNHO-2014-2741
# ECLI-NL-RBGEL-2013-CA2377
# ECLI-NL-GHSHE-2021-680
# ECLI-NL-RBNHO-2022-10913
# ECLI-NL-RBGRO-2010-BL2506
# ECLI-NL-RBMNE-2015-1327
# ECLI-NL-RBHAA-2008-BC7575
# ECLI-NL-RBHAA-2008-BC7534
# ECLI-NL-RBNHO-2021-4246
# ECLI-NL-GHARL-2020-4887
# ECLI-NL-GHSHE-2012-BY4108
# ECLI-NL-RBSHE-2012-BW8610
# ECLI-NL-GHAMS-2021-2818
# ECLI-NL-RBGEL-2013-CA2302
# ECLI-NL-RBOBR-2021-5911
# ECLI-NL-RBZWB-2018-3670
# ECLI-NL-GHARL-2022-10544
# ECLI-NL-RBOBR-2021-4269
# ECLI-NL-RBZLY-2011-BQ4832
# ECLI-NL-RBROT-2022-8862
# ECLI-NL-RBNHO-2020-6349
# ECLI-NL-RBZWB-2021-5856
# ECLI-NL-GHSHE-2022-1991
# ECLI-NL-HR-2013-BZ3622
# ECLI-NL-GHSHE-2020-3940
# ECLI-NL-RBMNE-2021-3972
# ECLI-NL-RBAMS-2021-4473
# ECLI-NL-RBROT-2021-8810
# ECLI-NL-RBGEL-2015-8258
# ECLI-NL-RBROT-2019-1733
# ECLI-NL-GHSHE-2009-BH1269
# ECLI-NL-RBOVE-2022-2168
# ECLI-NL-RBMNE-2022-1478
# ECLI-NL-RBOVE-2017-4542
# ECLI-NL-RBGEL-2013-5827
# ECLI-NL-GHARN-2010-BO8913
# ECLI-NL-RBLIM-2020-4856
# ECLI-NL-RBROT-2021-7764
# ECLI-NL-GHSGR-2011-BR5059
# ECLI-NL-RBHAA-2009-BI7131
# ECLI-NL-RBLIM-2022-3228
# ECLI-NL-RBROT-2018-5206
# ECLI-NL-RBAMS-2019-7743
# ECLI-NL-RBOBR-2015-1297
# ECLI-NL-GHAMS-2017-4736
# ECLI-NL-RBOBR-2020-1201
# ECLI-NL-GHSGR-2012-BX4063
# ECLI-NL-GHAMS-2021-3351
# ECLI-NL-RBDOR-2007-BB6524
# ECLI-NL-RBROT-2022-10106
# ECLI-NL-RBROT-2009-BH1933
# ECLI-NL-RBNHO-2021-11494
# ECLI-NL-RBROT-2021-13212
# ECLI-NL-RBGEL-2020-7066
# ECLI-NL-PHR-2021-227
# ECLI-NL-RBROT-2022-3051
# ECLI-NL-RBSHE-2012-BW8620
# ECLI-NL-RBSGR-2005-AT9194
# ECLI-NL-RBMNE-2021-1767
# ECLI-NL-RBGEL-2021-1847
# ECLI-NL-RBOVE-2020-1592
# ECLI-NL-RBOVE-2020-1587
# ECLI-NL-RBOVE-2020-1589
# ECLI-NL-RBOVE-2020-1596
# ECLI-NL-RBOVE-2020-1597
# ECLI-NL-RBOBR-2019-5938
# ECLI-NL-RBLIM-2019-4835
# ECLI-NL-RBOVE-2016-745
# ECLI-NL-GHSGR-2010-BO1006
# ECLI-NL-RBALM-2008-BC6750
# ECLI-NL-RBHAA-2004-AO4855
# ECLI-NL-GHSGR-2003-AI0975
# ECLI-NL-GHSGR-2012-BW5076
# ECLI-NL-RBROT-2021-198
# ECLI-NL-GHAMS-2019-2441
# ECLI-NL-RBLIM-2017-6869
# ECLI-NL-RBLIM-2020-4254
# ECLI-NL-RBLIM-2022-7297
# ECLI-NL-RBROT-2018-2484
# ECLI-NL-RBARN-2011-BU5637
# ECLI-NL-RBZUT-2009-BI1174
# ECLI-NL-RBSGR-2008-BE8729
# ECLI-NL-RBUTR-2012-BX0885
# ECLI-NL-RBROT-2022-3052
# ECLI-NL-RBLIM-2021-8799
# ECLI-NL-GHAMS-2010-BN7285
# ECLI-NL-GHAMS-2017-20
# ECLI-NL-RBOVE-2015-638
# ECLI-NL-RBHAA-2012-5275
# ECLI-NL-RBZWB-2022-3725
# ECLI-NL-RBSGR-2005-AT9230
# ECLI-NL-RBSGR-2005-AT9184
# ECLI-NL-RBAMS-2022-5998
# ECLI-NL-GHSGR-2012-BY9741
# ECLI-NL-OGHACMB-2012-BX7516
# ECLI-NL-RBOBR-2016-4325
# ECLI-NL-RBGEL-2020-7018
# ECLI-NL-RBROT-2022-2847
# ECLI-NL-RBAMS-2012-BY8841
# ECLI-NL-RBSGR-2005-AT9224
# ECLI-NL-CRVB-2019-3707
# ECLI-NL-GHSHE-2005-AS6602
# ECLI-NL-RBBRE-2011-BO9572
# ECLI-NL-GHAMS-2021-1722
# ECLI-NL-OGHNAA-2010-BM4258
# ECLI-NL-RBAMS-2021-7155
# ECLI-NL-RBHAA-2011-BS8737
# ECLI-NL-RBOVE-2014-4051
# ECLI-NL-GHAMS-2020-2758
# ECLI-NL-RBZUT-2010-BM5520
# ECLI-NL-RBZWB-2021-1988
# ECLI-NL-RBGEL-2015-1727
# ECLI-NL-RBOBR-2018-74
# ECLI-NL-RBROT-2022-4941
# ECLI-NL-RBGRO-2010-BL2673
# ECLI-NL-RBBRE-2004-AO4764
# ECLI-NL-RBNNE-2013-1431
# ECLI-NL-RBOVE-2021-795
# ECLI-NL-RBMNE-2021-233
# ECLI-NL-RBROT-2020-2749
# ECLI-NL-RBOBR-2018-1245
# ECLI-NL-RBROT-2019-5151
# ECLI-NL-RBGEL-2014-1050
# ECLI-NL-RBZWB-2021-1987
# ECLI-NL-RBNHO-2021-12182
# ECLI-NL-RBOVE-2017-1979
# ECLI-NL-RBLIM-2019-10390
# ECLI-NL-OGHNAA-2008-BG4542
# ECLI-NL-GHARL-2020-5393
# ECLI-NL-RBSHE-2007-BC0691
# ECLI-NL-RBROT-2008-BG7481
# ECLI-NL-RBOBR-2019-5939
# ECLI-NL-RBZWB-2017-7073
# ECLI-NL-RBOBR-2022-5425
# ECLI-NL-RBSGR-2005-AT9231
# ECLI-NL-RBDHA-2021-10081
# ECLI-NL-GHARL-2020-9104
# ECLI-NL-RBNHO-2014-12947
# ECLI-NL-RBSGR-2005-AT9189
# ECLI-NL-RBSGR-2005-AT9192
# ECLI-NL-GHSGR-2003-AN8613
# ECLI-NL-PHR-2021-229
# ECLI-NL-RBLIM-2017-6776
# ECLI-NL-GHARN-2011-BS8945
# ECLI-NL-PHR-2008-BC1309
# ECLI-NL-RBNNE-2020-1678
# ECLI-NL-RBROT-2020-11147
# ECLI-NL-GHSHE-2015-2450
# ECLI-NL-RBHAA-2009-BH1016
# ECLI-NL-RBMNE-2019-2632
# ECLI-NL-RBMNE-2019-2634
# ECLI-NL-RBMNE-2019-2638
# ECLI-NL-RBMNE-2019-2646
# ECLI-NL-RBMNE-2019-2670
# ECLI-NL-RBMNE-2019-2669
# ECLI-NL-RBMNE-2013-5174
# ECLI-NL-RBDHA-2022-1389
# ECLI-NL-GHSHE-2003-AF7616
# ECLI-NL-RBOVE-2021-3880
# ECLI-NL-RBGEL-2015-981
# ECLI-NL-GHSGR-2005-AS5775
# ECLI-NL-RBNNE-2017-1741
# ECLI-NL-RBROT-2021-11390
# ECLI-NL-RBMNE-2022-3399
# ECLI-NL-GHSHE-2008-BF1771
# ECLI-NL-GHLEE-2004-AR2396
# ECLI-NL-RBNNE-2020-4632
# ECLI-NL-RBROT-2019-5135
# ECLI-NL-RBHAA-2011-BU4121
# ECLI-NL-RBLIM-2022-988
# ECLI-NL-RBDHA-2019-3444
# ECLI-NL-RBDHA-2019-5424
# ECLI-NL-RBARN-2012-BX7949
# ECLI-NL-GHSHE-2022-2035
# ECLI-NL-GHSHE-2002-AF9145
# ECLI-NL-RBOVE-2021-4351
# ECLI-NL-RBROT-2019-10916
# ECLI-NL-RBOBR-2013-BY9062
# ECLI-NL-RBASS-2006-AZ4191
# ECLI-NL-RBSGR-2005-AT9225
# ECLI-NL-RBNNE-2013-4872
# ECLI-NL-RBGEL-2022-3183
# ECLI-NL-RBOBR-2016-538
# ECLI-NL-PHR-2021-228
# ECLI-NL-RBZLY-2012-BY6566
# ECLI-NL-RBDHA-2022-3694
# ECLI-NL-RBNNE-2019-966
# ECLI-NL-RBSGR-2005-AT9229
# ECLI-NL-RBMAA-2008-BD4796
# ECLI-NL-RBMNE-2021-1766
# ECLI-NL-RVS-2020-2115
# ECLI-NL-RBROT-2019-3166
# ECLI-NL-RBZWB-2016-406
# ECLI-NL-GHSHE-2015-4091
# ECLI-NL-RBLIM-2013-12409
# ECLI-NL-RBAMS-2013-3848
# ECLI-NL-RBAMS-2013-3852
# ECLI-NL-HR-2010-BM9968
# ECLI-NL-PHR-2010-BM9968
# ECLI-NL-RBBRE-2004-AR7632
# ECLI-NL-RBNNE-2014-5334
# ECLI-NL-RBROT-2017-7458
# ECLI-NL-RBMNE-2016-4891
# ECLI-NL-GHARL-2014-4097
# ECLI-NL-RBLIM-2021-8808
# ECLI-NL-RBAMS-2016-863
# ECLI-NL-GHAMS-2019-4263
# ECLI-NL-RBNNE-2014-6141
# ECLI-NL-RBOVE-2013-BZ9338
# ECLI-NL-CRVB-2010-BM8227
# ECLI-NL-PHR-2021-226
# ECLI-NL-RBMNE-2021-6338
# ECLI-NL-RBOBR-2019-679
# ECLI-NL-RBROT-2010-BO3803
# ECLI-NL-RBDHA-2022-5325
# ECLI-NL-RBSHE-2011-BR4204
# ECLI-NL-RBZUT-2009-BI0965
# ECLI-NL-GHAMS-2002-AE2873
# ECLI-NL-RBMNE-2014-6428
# ECLI-NL-RBMNE-2021-1285
# ECLI-NL-RBOVE-2020-104
# ECLI-NL-GHSHE-2017-135
# ECLI-NL-GHAMS-2019-2929
# ECLI-NL-RBMAA-2011-BQ6889
# ECLI-NL-GHSGR-2011-BP2200
# ECLI-NL-RBAMS-2008-BF0363
# ECLI-NL-GHARN-2004-AR8605
# ECLI-NL-PHR-2021-193
# ECLI-NL-GHAMS-2020-3064
# ECLI-NL-GHARN-2007-BA8480
# ECLI-NL-RBROE-2006-AZ2572
# ECLI-NL-RBROT-2021-11392
# ECLI-NL-RBUTR-2011-BR2390
# ECLI-NL-RBASS-2009-BI9307
# ECLI-NL-RBLIM-2018-2976
# ECLI-NL-RBSGR-2007-BA0918
# ECLI-NL-RBZUT-2008-BC9786
# ECLI-NL-RBOVE-2018-3395
# ECLI-NL-RBGEL-2015-1757
# ECLI-NL-RBROT-2017-4625
# ECLI-NL-RBMNE-2015-1209
# ECLI-NL-GHLEE-2009-BI2564
# ECLI-NL-RBOVE-2016-2773
# ECLI-NL-RBROT-2020-7219
# ECLI-NL-RBNNE-2019-4608
# ECLI-NL-RBOVE-2022-575
# ECLI-NL-RBNNE-2014-5336
# ECLI-NL-RBAMS-2020-5771
# ECLI-NL-GHAMS-2019-4997
# ECLI-NL-PHR-2022-877
# ECLI-NL-RBOBR-2022-2365
# ECLI-NL-GHARL-2018-11025
# ECLI-NL-RBZWB-2021-2019
# ECLI-NL-RBOVE-2020-2572
# ECLI-NL-RBMNE-2014-4793
# ECLI-NL-GHSHE-2007-BB7470
# ECLI-NL-RBNNE-2021-165
# ECLI-NL-RBZUT-2010-BM6779
# ECLI-NL-RBHAA-2012-BX4502
# ECLI-NL-RBHAA-2012-BX3464
# ECLI-NL-RBZWB-2019-4781
# ECLI-NL-GHSHE-2009-BJ4241
# ECLI-NL-RBASS-2007-BA1104
# ECLI-NL-RBROT-2021-1183
# ECLI-NL-RBROT-2022-8684
# ECLI-NL-RBSGR-2010-BO8548
# ECLI-NL-RBUTR-2009-BJ2252
# ECLI-NL-RBZWB-2020-729
# ECLI-NL-GHAMS-2018-336
# ECLI-NL-OGEAA-2015-578
# ECLI-NL-RBOVE-2015-3600
# ECLI-NL-RBNNE-2014-5718
# ECLI-NL-RBOBR-2014-5187
# ECLI-NL-GHDHA-2013-4590
# ECLI-NL-RBDHA-2021-6368
# ECLI-NL-RBOVE-2021-1698
# ECLI-NL-PHR-2006-AV7213
# ECLI-NL-RBMNE-2019-991
# ECLI-NL-PHR-2021-786
# ECLI-NL-RBMNE-2017-491
# ECLI-NL-RBMNE-2021-4480
# ECLI-NL-RBGEL-2021-2099
# ECLI-NL-RBGEL-2014-897
# ECLI-NL-RBROT-2020-12313
# ECLI-NL-PHR-2019-1247
# ECLI-NL-GHSHE-2003-AO9091
# ECLI-NL-GHAMS-2021-2819
# ECLI-NL-RBOBR-2015-2754
# ECLI-NL-RBMNE-2022-2201
# ECLI-NL-RBLIM-2020-4408
# ECLI-NL-GHARL-2018-8115
# ECLI-NL-RBMNE-2020-3691
# ECLI-NL-RBROT-2020-2472
# ECLI-NL-RBROT-2018-3139
# ECLI-NL-GHDHA-2014-326
# ECLI-NL-OGEAA-2018-856
# ECLI-NL-RBOVE-2020-1256
# ECLI-NL-RBAMS-2022-3886
# ECLI-NL-RBNNE-2021-2727
# ECLI-NL-GHSHE-2019-3857
# ECLI-NL-RBLIM-2021-8796
# ECLI-NL-RBROT-2021-1546
# ECLI-NL-RBROT-2020-12042
# ECLI-NL-RBMNE-2020-66
# ECLI-NL-RBOBR-2022-2501
# ECLI-NL-RVS-2021-2704
# ECLI-NL-RBOBR-2021-4716
# ECLI-NL-PHR-2020-1224
# ECLI-NL-PHR-2020-1225
# ECLI-NL-RBROT-2018-4536
# ECLI-NL-RBSGR-2008-BG6733
# ECLI-NL-GHAMS-2015-4299
# ECLI-NL-RBHAA-2009-BJ6460
# ECLI-NL-RBLIM-2013-CA0957
# ECLI-NL-RBBRE-2007-AZ8028
# ECLI-NL-RBZWB-2015-6490
# ECLI-NL-RBHAA-2012-BW9286
# ECLI-NL-RBOVE-2022-833
# ECLI-NL-RBROT-2021-10317
# ECLI-NL-RBROT-2019-8747
# ECLI-NL-HR-2019-385
# ECLI-NL-RBSHE-2012-BW8533
# ECLI-NL-GHAMS-2021-324
# ECLI-NL-RBROT-2022-2451
# ECLI-NL-RBOVE-2020-2627
# ECLI-NL-GHARL-2020-5155
# ECLI-NL-PHR-2020-865
# ECLI-NL-RBNHO-2017-3665
# ECLI-NL-OGEAA-2021-329
# ECLI-NL-RBLIM-2021-8810
# ECLI-NL-RBHAA-2012-BX3799
# ECLI-NL-RBMNE-2020-58
# ECLI-NL-OGHNAA-2009-BJ7644
# ECLI-NL-RBDHA-2022-7848
# ECLI-NL-RBOVE-2015-3233
# ECLI-NL-GHSGR-2003-AI0937
# ECLI-NL-GHDHA-2013-BZ9214
# ECLI-NL-RBLIM-2022-6615
# ECLI-NL-GHSHE-2011-BU4621
# ECLI-NL-RBNNE-2020-99
# ECLI-NL-RBGEL-2021-2166
# ECLI-NL-RBOVE-2020-2562
# ECLI-NL-RBROT-2021-807
# ECLI-NL-RBROE-2007-BC1063
# ECLI-NL-RBROT-2021-13167
# ECLI-NL-RBZWB-2019-3756
# ECLI-NL-RBHAA-2009-BL6396
# ECLI-NL-RBMNE-2015-1838
# ECLI-NL-RBARN-2011-BU6875
# ECLI-NL-RBROT-2012-BY4563
# ECLI-NL-GHARN-2008-BG7398
# ECLI-NL-GHARL-2021-10682
# ECLI-NL-RBGEL-2022-2744
# ECLI-NL-RBGEL-2022-2745
# ECLI-NL-RBUTR-2012-BX6183
# ECLI-NL-RBZLY-2012-BY1189
# ECLI-NL-GHSHE-2006-AZ4125
# ECLI-NL-PHR-2007-BA2269
# ECLI-NL-GHDHA-2017-3641
# ECLI-NL-RBMNE-2016-4457
# ECLI-NL-RBDHA-2018-14207
# ECLI-NL-RBDHA-2020-4550
# ECLI-NL-RBDHA-2020-4633
# ECLI-NL-RBLIM-2021-5004
# ECLI-NL-RBUTR-2011-BT8371
# ECLI-NL-RBOVE-2020-2856
# ECLI-NL-GHAMS-2017-4735
# ECLI-NL-RBOVE-2020-2561
# ECLI-NL-RBOBR-2020-1044
# ECLI-NL-RBZWB-2021-1439
# ECLI-NL-RBDHA-2020-4553
# ECLI-NL-RBLIM-2022-3227
# ECLI-NL-GHLEE-2011-BP4997
# ECLI-NL-RBOBR-2022-5638
# ECLI-NL-RBDHA-2019-3030
# ECLI-NL-RBDHA-2021-284
# ECLI-NL-RBUTR-2012-BW7467
# ECLI-NL-RBZWB-2021-1986
# ECLI-NL-OGEAA-2017-224
# ECLI-NL-RBALM-2007-BB5111
# ECLI-NL-GHSHE-2012-BY4113
# ECLI-NL-RBDOR-2006-AV3148
# ECLI-NL-RBNNE-2016-2295
# ECLI-NL-GHSHE-2017-1082
# ECLI-NL-HR-2007-BA2269
# ECLI-NL-RBZUT-2012-BW1489
# ECLI-NL-PHR-2008-BE9817
# ECLI-NL-RBROT-2018-5836
# ECLI-NL-GHSHE-2017-3072
# ECLI-NL-GHSHE-2016-1219
# ECLI-NL-RBNHO-2020-2720
# ECLI-NL-RBMNE-2019-4296
# ECLI-NL-RBOBR-2020-5627
# ECLI-NL-RBMNE-2020-4455
# ECLI-NL-RBDHA-2017-827
# ECLI-NL-RBOBR-2020-601
# ECLI-NL-RBMNE-2022-1954
# ECLI-NL-RBDHA-2014-16677
# ECLI-NL-RBMNE-2021-231
# ECLI-NL-GHARL-2021-8393
# ECLI-NL-RBNNE-2021-3544
# ECLI-NL-RBMNE-2019-6685
# ECLI-NL-RBNNE-2018-5262
# ECLI-NL-RBMID-2011-BP7843
# ECLI-NL-RBMID-2011-BP7867
# ECLI-NL-RBNNE-2018-3658
# ECLI-NL-RBHAA-2010-BO9375
# ECLI-NL-PHR-2016-96
# ECLI-NL-RBMNE-2022-490
# ECLI-NL-RBMNE-2022-1481
# ECLI-NL-HR-2021-732
# ECLI-NL-RBOBR-2020-3545
# ECLI-NL-RBASS-2009-BJ6345
# ECLI-NL-RBNNE-2016-626
# ECLI-NL-RBUTR-2009-BJ2167
# ECLI-NL-RBROT-2019-4770
# ECLI-NL-RBOBR-2017-3710
# ECLI-NL-RBZWB-2015-995
# ECLI-NL-RVS-2021-1150
# ECLI-NL-HR-2020-9
# ECLI-NL-PHR-2019-1389
# ECLI-NL-RBNNE-2017-843
# ECLI-NL-RBNNE-2015-1266
# ECLI-NL-RBARN-2011-BT6486
# ECLI-NL-RBARN-2011-BT6488
# ECLI-NL-RBARN-2011-BT6491
# ECLI-NL-RBDHA-2019-3029
# ECLI-NL-HR-2014-2756
# ECLI-NL-RBROT-2017-10337
# ECLI-NL-RBOBR-2014-6474
# ECLI-NL-RBMNE-2020-1305
# ECLI-NL-RBOBR-2017-2217
# ECLI-NL-RBMNE-2020-4125
# ECLI-NL-RBOBR-2017-2216
# ECLI-NL-GHARN-2009-BK7216
# ECLI-NL-OGHNAA-2009-BJ7639
# ECLI-NL-PHR-2018-611
# ECLI-NL-RBSGR-2008-BG8391
# ECLI-NL-RBNNE-2016-2847
# ECLI-NL-GHARL-2020-10504
# ECLI-NL-GHSHE-2018-1974
# ECLI-NL-RBROT-2020-6160
# ECLI-NL-RBOBR-2020-2726
# ECLI-NL-RBDHA-2018-14213
# ECLI-NL-RBGEL-2017-6553
# ECLI-NL-RBHAA-2011-BS1554
# ECLI-NL-RBAMS-2008-BF0262
# ECLI-NL-RBONE-2013-BZ2717
# ECLI-NL-GHAMS-2012-BW6604
# ECLI-NL-GHARN-2006-AV6348
# ECLI-NL-RBSGR-2004-AO9178
# ECLI-NL-RBHAA-2012-BX4250
# ECLI-NL-RBLIM-2015-3485
# ECLI-NL-HR-2019-92
# ECLI-NL-GHSGR-2008-BF3685
# ECLI-NL-RBALM-2010-BL2943
# ECLI-NL-RBOBR-2021-4715
# ECLI-NL-RBGEL-2021-4146
# ECLI-NL-RBOBR-2021-237
# ECLI-NL-RBOBR-2022-2242
# ECLI-NL-RBSGR-2011-BP4426
# ECLI-NL-RBNHO-2014-4638
# ECLI-NL-RBROT-2018-9304
# ECLI-NL-OGHACMB-2015-40
# ECLI-NL-RBMNE-2021-1039
# ECLI-NL-RBMNE-2021-1284
# ECLI-NL-RBZUT-2007-AZ9738
# ECLI-NL-GHARN-2005-AT9153
# ECLI-NL-GHSHE-2015-595
# ECLI-NL-RBROT-2008-BG7493
# ECLI-NL-RBROT-2022-5933
# ECLI-NL-RBOBR-2020-1035
# ECLI-NL-RBOVE-2021-1307
# ECLI-NL-RBROT-2022-3303
# ECLI-NL-RBNNE-2015-6378
# ECLI-NL-GHLEE-2009-BK0591
# ECLI-NL-GHDHA-2017-3418
# ECLI-NL-RBGEL-2021-2620
# ECLI-NL-RBDHA-2022-3693
# ECLI-NL-RBDHA-2021-11798
# ECLI-NL-PHR-2017-269
# ECLI-NL-RBGEL-2020-3631
# ECLI-NL-RBNNE-2015-6377
# ECLI-NL-RBOVE-2019-826
# ECLI-NL-PHR-2009-BG5608
# ECLI-NL-GHLEE-2003-AO1223
# ECLI-NL-RBROT-2020-2548
# ECLI-NL-RBNHO-2022-6714
# ECLI-NL-RBOVE-2019-701
# ECLI-NL-GHLEE-2011-BP6422
# ECLI-NL-RVS-2018-2526
# ECLI-NL-RBOVE-2020-1960
# ECLI-NL-RBDHA-2021-14529
# ECLI-NL-RBROT-2018-8294
# ECLI-NL-RBZWB-2020-6690
# ECLI-NL-GHARN-2004-AP8401
# ECLI-NL-RBDHA-2020-10950
# ECLI-NL-RBROT-2022-6745
# ECLI-NL-RBUTR-2012-BX7882
# ECLI-NL-RBHAA-2012-BX4050
# ECLI-NL-RBHAA-2011-BS1551
# ECLI-NL-RBNNE-2016-3130
# ECLI-NL-RBROT-2019-7606
# ECLI-NL-RBSHE-2012-BY6600
# ...
# ECLI-NL-RBNNE-2016-2607
# ECLI-NL-RBROT-2022-6711
# ECLI-NL-RBSGR-2012-BY7120
# ECLI-NL-RBNHO-2022-11548
# ECLI-NL-RBMNE-2022-5660
# ECLI-NL-GHSHE-2020-3637
# ECLI-NL-RBDHA-2018-6519
# ECLI-NL-RBZUT-2011-BT7065
# ECLI-NL-RBAMS-2009-BR2146
# ECLI-NL-PHR-2020-934
# ECLI-NL-PHR-2019-1019
# ECLI-NL-RBDHA-2015-14076
# ECLI-NL-RBROT-2020-8302
# ECLI-NL-RBDHA-2019-9764
# ECLI-NL-RBAMS-2013-8460
# ECLI-NL-GHAMS-2021-1623
# ECLI-NL-PHR-2002-AE2761
# ECLI-NL-RBAMS-2020-4875
# ECLI-NL-RBDHA-2020-924
# ECLI-NL-RBNNE-2017-1851
# ECLI-NL-RBNNE-2017-1642
# ECLI-NL-RBSHE-2009-BH6954
# ECLI-NL-PHR-2022-271
# ECLI-NL-RBMNE-2022-225
# ECLI-NL-RBNHO-2021-11938
# ECLI-NL-RBOBR-2021-4266
# ECLI-NL-RBLIM-2021-1561
# ECLI-NL-RBAMS-2021-546
# ECLI-NL-RBOBR-2020-6142
# ECLI-NL-PHR-2020-817
# ECLI-NL-RBNNE-2020-3142
# ECLI-NL-GHDHA-2020-1306
# ECLI-NL-PHR-2019-569
# ECLI-NL-PHR-2019-318
# ECLI-NL-GHARL-2018-10982
# ECLI-NL-RBDHA-2018-7899
# ECLI-NL-RBGEL-2017-337
# ECLI-NL-GHARL-2016-4568
# ECLI-NL-GHSHE-2016-1135
# ECLI-NL-RBOVE-2016-72
# ECLI-NL-RBLIM-2015-9799
# ECLI-NL-GHSHE-2015-4354
# ECLI-NL-RBGEL-2014-6438
# ECLI-NL-RBAMS-2013-BZ2812
# ECLI-NL-RBUTR-2012-BY7842
# ECLI-NL-RBUTR-2012-BY0022
# ECLI-NL-RBZUT-2012-BX4177
# ECLI-NL-RBLEE-2011-BU9123
# ECLI-NL-RBALK-2010-BO9282
# ECLI-NL-RBUTR-2008-BD6965
# ECLI-NL-RBZUT-2003-AF3006
# ECLI-NL-RBROT-2021-4023
# ECLI-NL-GHARL-2013-9961
# ECLI-NL-RBMNE-2022-2509
# ECLI-NL-GHSHE-2019-3671
# ECLI-NL-RBDHA-2016-15309
# ECLI-NL-PHR-2013-CA0265
# ECLI-NL-RBOBR-2013-BZ0217
# ECLI-NL-PHR-2005-AS5238
# ECLI-NL-RBROT-2022-6715
# ECLI-NL-RBNHO-2022-3833
# ECLI-NL-RBOBR-2013-BZ9551
# ECLI-NL-RBDHA-2022-9733
# ECLI-NL-RBOBR-2022-4022
# ECLI-NL-RBDHA-2022-8486
# ECLI-NL-RBDHA-2022-6440
# ECLI-NL-RBAMS-2022-2091
# ECLI-NL-RBNNE-2022-763
# ECLI-NL-RBMNE-2021-6703
# ECLI-NL-RBMNE-2021-4333
# ECLI-NL-RBNNE-2021-1389
# ECLI-NL-GHDHA-2021-9
# ECLI-NL-GHDHA-2020-2423
# ECLI-NL-RBZWB-2020-5682
# ECLI-NL-RBNNE-2020-3371
# ECLI-NL-RBROT-2020-9214
# ECLI-NL-RBMNE-2020-3324
# ECLI-NL-RBMNE-2020-2763
# ECLI-NL-RBGEL-2020-3195
# ECLI-NL-RBOBR-2020-3187
# ECLI-NL-RBLIM-2020-1017
# ECLI-NL-GHDHA-2018-1774
# ECLI-NL-GHARL-2018-6553
# ECLI-NL-RBLIM-2017-11552
# ECLI-NL-RBGEL-2017-4467
# ECLI-NL-GHAMS-2016-1215
# ECLI-NL-RBNHO-2016-1916
# ECLI-NL-RBROT-2015-7041
# ECLI-NL-RBMNE-2015-9620
# ECLI-NL-RBOBR-2014-7001
# ECLI-NL-RBZWB-2014-4144
# ECLI-NL-RBDHA-2013-BZ3920
# ECLI-NL-RBALK-2012-BW0239
# ECLI-NL-GHSHE-2011-BP1071
# ECLI-NL-RBASS-2010-BM2269
# ECLI-NL-RBAMS-2009-BH1786
# ECLI-NL-RVS-2008-BE9698
# ECLI-NL-RBUTR-2008-BD6969
# ECLI-NL-GHSHE-2007-BC0238
# ECLI-NL-RBMNE-2022-807
# ECLI-NL-RBNNE-2014-1005
# ECLI-NL-RBGEL-2022-5489
# ECLI-NL-PHR-2022-24
# ECLI-NL-RBDHA-2015-1885
# ECLI-NL-RBGEL-2019-4277
# ECLI-NL-RBMNE-2017-6279
# ECLI-NL-GHARN-2006-AX5818
# ECLI-NL-HR-1994-AD2076
# ECLI-NL-RBNNE-2013-BZ3265
# ECLI-NL-RBNHO-2022-11440
# ECLI-NL-GHAMS-2020-2517
# ECLI-NL-GHDHA-2019-1974
# ECLI-NL-RBNNE-2019-1712
# ECLI-NL-RBNNE-2018-1582
# ECLI-NL-RBDHA-2016-3902
# ECLI-NL-RBOBR-2015-2814
# ECLI-NL-RBAMS-2009-BI3717
# ECLI-NL-RBLIM-2021-9171
# ECLI-NL-RBNNE-2017-909
# ECLI-NL-PHR-2013-BZ3640
# ECLI-NL-GHAMS-2021-644
# ECLI-NL-RBNNE-2018-2242
# ECLI-NL-GHARL-2013-BZ9116
# ECLI-NL-RBALK-2007-BA7323
# ECLI-NL-PHR-2022-16
# ECLI-NL-RBMNE-2016-1039
# ECLI-NL-RBAMS-2022-2616
# ECLI-NL-RBNHO-2022-3899
# ECLI-NL-RBMNE-2022-704
# ECLI-NL-RBNHO-2022-3844
# ECLI-NL-RBROE-2009-BK5932
# ECLI-NL-RBMNE-2022-2956
# ECLI-NL-OGHACMB-2022-147
# ECLI-NL-RBNNE-2021-3007
# ECLI-NL-RBOVE-2021-2570
# ECLI-NL-GHSHE-2021-1448
# ECLI-NL-PHR-2019-625
# ECLI-NL-RBGEL-2018-2776
# ECLI-NL-RBDHA-2016-6473
# ECLI-NL-GHAMS-2010-BO2550
# ECLI-NL-PHR-2001-AB1471
# ECLI-NL-RBOBR-2020-742
# ECLI-NL-PHR-2015-477
# ECLI-NL-RBROT-2022-6703
# ECLI-NL-GHSHE-2009-BI0780
# ECLI-NL-RBNNE-2022-3573
# ECLI-NL-RBGEL-2022-5104
# ECLI-NL-PHR-2022-504
# ECLI-NL-RBROT-2021-4399
# ECLI-NL-RBOVE-2020-4214
# ECLI-NL-RBNHO-2019-8313
# ECLI-NL-RBNHO-2019-8314
# ECLI-NL-RBROT-2019-7599
# ECLI-NL-OGEAC-2018-347
# ECLI-NL-GHSHE-2018-1464
# ECLI-NL-PHR-2018-718
# ECLI-NL-RBNNE-2018-755
# ECLI-NL-PHR-2018-109
# ECLI-NL-RBLIM-2017-3330
# ECLI-NL-RBDHA-2017-3776
# ECLI-NL-RBGEL-2016-4527
# ECLI-NL-RBLIM-2015-9441
# ECLI-NL-RBMNE-2015-3302
# ECLI-NL-RBLIM-2013-BZ7297
# ECLI-NL-RBSHE-2012-BV3793
# ECLI-NL-RBZUT-2010-BM6487
# ECLI-NL-RBGRO-2010-BL5535
# ECLI-NL-RBAMS-2009-BI2884
# ECLI-NL-RBZUT-2008-BD6049
# ECLI-NL-RBALK-2007-BA7147
# ECLI-NL-GHSGR-2007-BA1903
# ECLI-NL-RBMNE-2022-804
# ECLI-NL-RBOBR-2018-4643
# ECLI-NL-PHR-2016-42
# ECLI-NL-RBNHO-2015-8235
# ECLI-NL-RBROT-2022-647
# ECLI-NL-RBMNE-2021-3998
# ECLI-NL-RBNNE-2021-1955
# ECLI-NL-RBOBR-2021-1665
# ECLI-NL-RBNHO-2021-2936
# ECLI-NL-PHR-2021-381
# ECLI-NL-PHR-2019-984
# ECLI-NL-RBDHA-2019-3695
# ECLI-NL-OGEABES-2017-11
# ECLI-NL-RBNNE-2015-6131
# ECLI-NL-RBNNE-2015-656
# ECLI-NL-RBLIM-2013-BZ7293
# ECLI-NL-RBROT-2011-BP9371
# ECLI-NL-RBMAA-2008-BG5181
# ECLI-NL-RBUTR-2008-BD6972
# ECLI-NL-PHR-2022-427
# ECLI-NL-RBNHO-2013-9110
# ECLI-NL-RBMNE-2020-4855
# ECLI-NL-RBSGR-2011-BU2899
# ECLI-NL-RBAMS-2011-BQ6036
# ECLI-NL-RBLIM-2019-11664
# ECLI-NL-RBNHO-2019-773
# ECLI-NL-RBOVE-2014-213
# ECLI-NL-GHARL-2021-2581
# ECLI-NL-RBLIM-2015-6026
# ECLI-NL-GHAMS-2012-BY0657
# ECLI-NL-PHR-2000-AA7257
# ECLI-NL-RBNNE-2021-3254
# ECLI-NL-RBOVE-2021-4540
# ECLI-NL-RBDHA-2022-10915
# ECLI-NL-RBDHA-2021-13978
# ECLI-NL-RBAMS-2018-8378
# ECLI-NL-RBAMS-2021-7612
# ECLI-NL-PHR-2020-457
# ECLI-NL-RBMNE-2019-6155
# ECLI-NL-RBNHO-2019-7674
# ECLI-NL-RBNHO-2016-9103
# ECLI-NL-RBOVE-2016-4134
# ECLI-NL-RBNHO-2014-13118
# ECLI-NL-RBOVE-2014-898
# ECLI-NL-PHR-2007-AZ2475
# ECLI-NL-HR-2019-1983
# ECLI-NL-RBDHA-2018-1704
# ECLI-NL-PHR-2016-1434
# ECLI-NL-RBZWB-2016-4648
# ECLI-NL-RBDHA-2013-19439
# ECLI-NL-PHR-2013-820
# ECLI-NL-PHR-2013-821
# ECLI-NL-RBMNE-2020-3912
# ECLI-NL-GHAMS-2015-4436
# ECLI-NL-RBMNE-2020-2683
# ECLI-NL-RBSGR-2011-BU2120
# ECLI-NL-GHDHA-2014-4737
# ECLI-NL-GHAMS-2021-3584
# ECLI-NL-RBLIM-2022-8959
# ECLI-NL-RBDHA-2021-8710
# ECLI-NL-RBMNE-2021-2508
# ECLI-NL-RBNHO-2019-585
# ECLI-NL-RBGEL-2019-205
# ECLI-NL-OGEAC-2018-193
# ECLI-NL-RBNNE-2018-857
# ECLI-NL-RBNHO-2017-6176
# ECLI-NL-RBOVE-2016-5116
# ECLI-NL-RBNNE-2015-4444
# ECLI-NL-GHSGR-2009-BI9646
# ECLI-NL-RBOBR-2020-5838
# ECLI-NL-RBNNE-2021-572
# ECLI-NL-RBLIM-2018-3323
# ECLI-NL-PHR-2022-64
# ECLI-NL-RBLIM-2022-10198
# ECLI-NL-RBDHA-2022-13115
# ECLI-NL-RBROT-2022-5878
# ECLI-NL-RBDHA-2022-5898
# ECLI-NL-RBLIM-2021-770
# ECLI-NL-RBMNE-2020-2448
# ECLI-NL-RBNNE-2019-4616
# ECLI-NL-RBOVE-2019-702
# ECLI-NL-OGEAC-2018-346
# ECLI-NL-OGEAC-2018-348
# ECLI-NL-PHR-2016-315
# ECLI-NL-PHR-2011-BT1805
# ECLI-NL-PHR-2011-BT1667
# ECLI-NL-PHR-2011-BT1804
# ECLI-NL-GHARN-2007-BB6874
# ECLI-NL-RBMNE-2016-7024
# ECLI-NL-GHARL-2022-8172
# ECLI-NL-RBMNE-2022-2529
# ECLI-NL-PHR-2019-1015
# ECLI-NL-RBMNE-2019-1448
# ECLI-NL-RBOBR-2021-6493
# ECLI-NL-RBDHA-2021-2660
# ECLI-NL-RBLIM-2015-6030
# ECLI-NL-RBLIM-2013-8496
# ECLI-NL-GHARN-2006-AX3969
# ECLI-NL-PHR-2021-1209
# ECLI-NL-RBNHO-2017-3375
# ECLI-NL-PHR-2013-835
# ECLI-NL-RBLEE-2010-BN2401
# ECLI-NL-GHARL-2022-3620
# ECLI-NL-RBMNE-2022-2540
# ECLI-NL-RBOBR-2016-5488
# ECLI-NL-GHSGR-2011-BW5191
# ECLI-NL-RBZUT-2010-BN0955
# ECLI-NL-RBROT-2022-6707
# ECLI-NL-RBNNE-2016-2104
# ECLI-NL-GHSGR-2000-AA6305
# ECLI-NL-RBAMS-2022-3781
# ECLI-NL-RBLIM-2020-9930
# ECLI-NL-GHAMS-2020-2518
# ECLI-NL-RBLIM-2017-3317
# ECLI-NL-RBGEL-2016-6716
# ECLI-NL-RBNHO-2016-9098
# ECLI-NL-RBNNE-2015-4443
# ECLI-NL-RBGEL-2014-1473
# ECLI-NL-RBAMS-2022-2621
# ECLI-NL-PHR-2010-BN0526
# ECLI-NL-PHR-2021-880
# ECLI-NL-GHSHE-2017-2006
# ECLI-NL-RBAMS-2014-7040
# ECLI-NL-GHAMS-2011-BQ1658
# ECLI-NL-RBMNE-2022-2534
# ECLI-NL-GHSHE-2021-4095
# ECLI-NL-RBMNE-2021-3983
# ECLI-NL-RBDHA-2020-1013
# ECLI-NL-RBMNE-2019-6152
# ECLI-NL-RBZWB-2019-5258
# ECLI-NL-RBOVE-2019-1882
# ECLI-NL-RBNHO-2019-992
# ECLI-NL-RBROT-2018-4613
# ECLI-NL-RBLIM-2016-6077
# ECLI-NL-RBLIM-2015-7627
# ECLI-NL-RBOBR-2014-2227
# ECLI-NL-RBZWB-2013-5858
# ECLI-NL-RBAMS-2013-3069
# ECLI-NL-GHARN-2012-BW4599
# ECLI-NL-GHARN-2012-BW4601
# ECLI-NL-GHLEE-2011-BR4889
# ECLI-NL-RBROE-2009-BH5427
# ECLI-NL-RBUTR-2008-BD6960
# ECLI-NL-HR-2006-AV1633
# ECLI-NL-PHR-2003-AF4232
# ECLI-NL-PHR-2020-570
# ECLI-NL-GHDHA-2022-2231
# ECLI-NL-GHSHE-2016-5646
# ECLI-NL-GHAMS-2016-2414
# ECLI-NL-RBAMS-2021-2732
# ECLI-NL-RBMNE-2020-4495
# ECLI-NL-RBDHA-2022-12819
# ECLI-NL-RBDHA-2022-9144
# ECLI-NL-RBMNE-2022-2752
# ECLI-NL-RBGEL-2022-3228
# ECLI-NL-RBAMS-2022-2452
# ECLI-NL-PHR-2022-294
# ECLI-NL-RBAMS-2022-1324
# ECLI-NL-RBDHA-2022-8279
# ECLI-NL-RBAMS-2022-573
# ECLI-NL-PHR-2022-4
# ECLI-NL-RBDHA-2022-83
# ECLI-NL-RBNHO-2021-11935
# ECLI-NL-PHR-2020-1040
# ECLI-NL-PHR-2020-839
# ECLI-NL-RBOVE-2019-4759
# ECLI-NL-PHR-2019-1354
# ECLI-NL-RBDHA-2019-8044
# ECLI-NL-RBZWB-2018-4709
# ECLI-NL-PHR-2018-714
# ECLI-NL-RBDHA-2018-7092
# ECLI-NL-RBNNE-2017-1693
# ECLI-NL-RBNNE-2017-1728
# ECLI-NL-GHSHE-2016-1121
# ECLI-NL-GHDHA-2015-1769
# ECLI-NL-RBMNE-2014-2736
# ECLI-NL-GHARL-2014-3917
# ECLI-NL-RBOBR-2013-CA1965
# ECLI-NL-RBZLY-2012-BY0691
# ECLI-NL-OGEANA-2009-BH6015
# ECLI-NL-RBZUT-2008-BG2157
# ECLI-NL-PHR-2007-BA7918
# ECLI-NL-RBBRE-2002-AE0456
# ECLI-NL-GHAMS-2016-1112
# ECLI-NL-RBAMS-2013-CA3399
# ECLI-NL-GHDHA-2022-2514
# ECLI-NL-PHR-2022-605
# ECLI-NL-GHAMS-2022-2248
# ECLI-NL-RBMNE-2022-2512
# ECLI-NL-RBMNE-2019-6178
# ECLI-NL-RBMNE-2019-6161
# ECLI-NL-RBNNE-2016-3096
# ECLI-NL-GHAMS-2016-1266
# ECLI-NL-RBSGR-2008-BD8808
# ECLI-NL-RBALK-2005-AU0040
# ECLI-NL-RBDHA-2022-10857
# ECLI-NL-GHARL-2020-10368
# ECLI-NL-RBROT-2019-3425
# ECLI-NL-RBNNE-2017-1596
# ECLI-NL-RBNNE-2014-5851
# ECLI-NL-RBMNE-2020-4051
# ECLI-NL-RBMNE-2020-4172
# ECLI-NL-RBDHA-2017-12021
# ECLI-NL-RBAMS-2018-1476
# ECLI-NL-RBAMS-2018-1475
# ECLI-NL-RBOVE-2022-2768
# ECLI-NL-RBZWB-2021-3606
# ECLI-NL-RBNNE-2021-887
# ECLI-NL-RBOVE-2020-3546
# ECLI-NL-RBAMS-2020-995
# ECLI-NL-RBLIM-2019-2503
# ECLI-NL-RBNNE-2015-6393
# ECLI-NL-RBMNE-2021-3893
# ECLI-NL-RBDHA-2020-6543
# ECLI-NL-RBUTR-2009-BJ1006
# ECLI-NL-RBMNE-2020-3908
# ECLI-NL-RBMNE-2020-4598
# ECLI-NL-RBOVE-2020-3678
# ECLI-NL-RBMNE-2022-2543
# ECLI-NL-GHSGR-2011-BW4158
# ECLI-NL-GHSGR-2011-BW5207
# ECLI-NL-RBSGR-2011-BQ9992
# ECLI-NL-RBOBR-2022-286
# ECLI-NL-RBOVE-2022-297
# ECLI-NL-RBDHA-2020-13460
# ECLI-NL-RBMNE-2019-2469
# ECLI-NL-RBDHA-2017-11341
# ECLI-NL-PHR-2017-654
# ECLI-NL-RBOBR-2017-294
# ECLI-NL-RBOBR-2014-2231
# ECLI-NL-RBGEL-2013-1485
# ECLI-NL-PHR-2012-BX5516
# ECLI-NL-RBALM-2011-BT8438
# ECLI-NL-PHR-2002-AE8772
# ECLI-NL-RBMNE-2020-3939
# ECLI-NL-RBDHA-2021-5046
# ECLI-NL-RBNHO-2019-584
# ECLI-NL-GHAMS-2018-1618
# ECLI-NL-RBNNE-2017-2449
# ECLI-NL-GHARL-2014-6940
# ECLI-NL-RBOVE-2014-3041
# ECLI-NL-RBSHE-2012-BW1330
# ECLI-NL-RBAMS-2010-BO4731
# ECLI-NL-RBMNE-2022-2507
# ECLI-NL-RBAMS-2011-BT7651
# ECLI-NL-RBNNE-2021-2433
# ECLI-NL-RBNHO-2019-7676
# ECLI-NL-RBNNE-2015-6392
# ECLI-NL-RBONE-2013-BZ2324
# ECLI-NL-RBNHO-2015-8190
# ECLI-NL-PHR-2020-1106
# ECLI-NL-RBNHO-2022-766
# ECLI-NL-RBUTR-2008-BD7125
# ECLI-NL-RBDHA-2020-3707
# ECLI-NL-RBOBR-2018-6624
# ECLI-NL-RBDHA-2018-10458
# ECLI-NL-RBROT-2018-6226
# ECLI-NL-RBNNE-2018-1307
# ECLI-NL-HR-2017-1017
# ECLI-NL-GHARN-2012-BW8652
# ECLI-NL-RBARN-2012-BW5491
# ECLI-NL-RBMID-2010-BM8173
# ECLI-NL-RBALK-2010-BL4598
# ECLI-NL-RBSHE-2009-BH2459
# ECLI-NL-RBSHE-2006-AY3910
# ECLI-NL-RBAMS-2021-5087
# ECLI-NL-RBDHA-2019-1609
# ECLI-NL-RBDHA-2013-19438
# ECLI-NL-RBDHA-2013-19437
# ECLI-NL-RVS-2011-BR2279
# ECLI-NL-RBDHA-2017-12018
# ECLI-NL-GHAMS-2022-2082
# ECLI-NL-GHSHE-2020-1730
# ECLI-NL-PHR-2014-521
# ECLI-NL-RBAMS-2022-7758
# ECLI-NL-GHDHA-2017-1344
# ECLI-NL-GHAMS-2016-1268
# ECLI-NL-PHR-2004-AH9789
# ECLI-NL-RBLIM-2017-2110
# ECLI-NL-PHR-2015-64
# ECLI-NL-RBNHO-2015-8231
# ECLI-NL-RBMNE-2021-5967
# ECLI-NL-RBMNE-2021-543
# ECLI-NL-PHR-2020-841
# ECLI-NL-PHR-2019-1125
# ECLI-NL-RBNHO-2017-6175
# ECLI-NL-RBNHO-2015-9231
# ECLI-NL-PHR-2015-156
# ECLI-NL-RBOVE-2013-2313
# ECLI-NL-RBMAA-2012-BW5816
# ECLI-NL-RBOBR-2017-2130
# ECLI-NL-RBNNE-2015-6385
# ECLI-NL-RBZWB-2019-1575
# ECLI-NL-RBDHA-2022-10836
# ECLI-NL-RBDHA-2022-10837
# ECLI-NL-PHR-2022-351
# ECLI-NL-RBAMS-2022-51
# ECLI-NL-RBROT-2019-10069
# ECLI-NL-RBROT-2021-9085
# ECLI-NL-RBMNE-2020-4310
# ECLI-NL-RBLIM-2018-3039
# ECLI-NL-GHDHA-2022-2505
# ECLI-NL-GHAMS-2022-298
# ECLI-NL-RBOVE-2021-2347
# ECLI-NL-RBGEL-2021-2550
# ECLI-NL-GHSHE-2021-1264
# ECLI-NL-RBDHA-2020-11386
# ECLI-NL-RBOBR-2019-3972
# ECLI-NL-RBGEL-2019-2136
# ECLI-NL-RBGEL-2018-3459
# ECLI-NL-GHDHA-2017-3770
# ECLI-NL-RBGEL-2017-949
# ECLI-NL-RBNHO-2016-232
# ECLI-NL-RBOVE-2015-5174
# ECLI-NL-RBMNE-2014-3183
# ECLI-NL-RBDHA-2014-8568
# ECLI-NL-RBNHO-2014-5212
# ECLI-NL-RBUTR-2011-BP7377
# ECLI-NL-PHR-2005-AR6459
# ECLI-NL-RBDHA-2018-3899
# ECLI-NL-RBOVE-2017-1818
# ECLI-NL-RBNHO-2015-4355
# ECLI-NL-RBAMS-2016-168
# ECLI-NL-RBNHO-2013-9657
# ECLI-NL-HR-1998-ZD1191
# ECLI-NL-RBZWB-2020-1492
# ECLI-NL-PHR-2016-1529
# ECLI-NL-RBNHO-2014-428
# ECLI-NL-RBMNE-2013-CA3877
# ECLI-NL-RBMAA-2012-BW5805
# ECLI-NL-RBSGR-2011-BR0143
# ECLI-NL-GHSHE-2019-1646
# ECLI-NL-PHR-2021-1143
# ECLI-NL-RBMNE-2019-1498
# ECLI-NL-PHR-2022-778
# ECLI-NL-RBOBR-2019-7731
# ECLI-NL-RBAMS-2018-3190
# ECLI-NL-RBAMS-2018-3196
# ECLI-NL-GHAMS-2016-1131
# ECLI-NL-RBNHO-2015-10448
# ECLI-NL-RBDHA-2022-11585
# ECLI-NL-RBNNE-2019-4085
# ECLI-NL-RBMNE-2022-2459
# ECLI-NL-RBMNE-2022-2508
# ECLI-NL-OGEAM-2019-53
# ECLI-NL-RBGEL-2015-6541
# ECLI-NL-PHR-2013-2659
# ECLI-NL-PHR-2009-BH1083
# ECLI-NL-RBAMS-2008-BG7225
# ECLI-NL-RBDHA-2018-3902
# ECLI-NL-RBDHA-2018-3907
# ECLI-NL-RBDHA-2022-11952
# ECLI-NL-RBZWB-2022-1404
# ECLI-NL-RBDHA-2020-7096
# ECLI-NL-GHARL-2013-7269
# ECLI-NL-RBROE-2008-BF2241
# ECLI-NL-PHR-2005-AR6458
# ECLI-NL-RBMNE-2022-2526
# ECLI-NL-PHR-2020-1262
# ECLI-NL-RBLIM-2020-9279
# ECLI-NL-RBMNE-2019-6156
# ECLI-NL-RBDHA-2016-12463
# ECLI-NL-RBNNE-2013-BY9376
# ECLI-NL-GHAMS-2021-3958
# ECLI-NL-GHARL-2021-11542
# ECLI-NL-RBROT-2022-5017
# ECLI-NL-RBAMS-2013-CA3400
# ECLI-NL-RBOVE-2021-1824
# ECLI-NL-GHAMS-2021-3956
# ECLI-NL-RBOVE-2020-3666
# ECLI-NL-PHR-2022-376
# ECLI-NL-PHR-2014-2728
# ECLI-NL-GHAMS-2022-2839
# ECLI-NL-GHAMS-2022-514
# ECLI-NL-RBDHA-2018-3901
# ECLI-NL-PHR-2022-375
# ECLI-NL-RBMNE-2022-5327
# ECLI-NL-PHR-2021-45
# ECLI-NL-RBOVE-2018-3656
# ECLI-NL-RBOBR-2015-3669
# ECLI-NL-PHR-2013-BX9906
# ECLI-NL-GHSHE-2017-2281
# ECLI-NL-PHR-2020-175
# ECLI-NL-RBLIM-2019-2219
# ECLI-NL-RBMNE-2019-1497
# ECLI-NL-RBLIM-2021-5493
# ECLI-NL-RBNNE-2021-888
# ECLI-NL-RBOBR-2018-6347
# ECLI-NL-RBAMS-2010-BL0547
# ECLI-NL-RBUTR-2008-BD6974
# ECLI-NL-RBMNE-2022-2467
# ECLI-NL-RBGEL-2020-3703
# ECLI-NL-GHSHE-2017-3990
# ECLI-NL-RBNNE-2022-2874
# ECLI-NL-PHR-2022-675
# ECLI-NL-RBOBR-2022-310
# ECLI-NL-RBLIM-2018-12331
# ECLI-NL-RBOBR-2018-6345
# ECLI-NL-RBSGR-2012-BX2996
# ECLI-NL-RBLIM-2020-9077
# ECLI-NL-RBLIM-2015-3471
# ECLI-NL-RBMNE-2022-2475
# ECLI-NL-RBMNE-2022-2531
# ECLI-NL-RBDHA-2018-3910
# ECLI-NL-RBROE-1995-1
# ECLI-NL-RBGEL-2022-4008
# ECLI-NL-RBLIM-2020-9270
# ECLI-NL-RBLIM-2020-9278
# ECLI-NL-RBOVE-2019-1347
# ECLI-NL-RBZWB-2019-786
# ECLI-NL-RBDHA-2019-72
# ECLI-NL-RBOBR-2018-6343
# ECLI-NL-RBDHA-2018-13748
# ECLI-NL-RBGEL-2017-5653
# ECLI-NL-RBAMS-2015-1446
# ECLI-NL-GHSHE-2010-BO4267
# ECLI-NL-RBMNE-2022-2511
# ECLI-NL-RBAMS-2021-5037
# ECLI-NL-RBOVE-2021-291
# ECLI-NL-PHR-2018-374
# ECLI-NL-GHAMS-2022-291
# ECLI-NL-RBOBR-2016-3718
# ECLI-NL-RBAMS-2010-BL3880
# ECLI-NL-RBSGR-2009-BH1760
# ECLI-NL-PHR-1995-15
# ECLI-NL-RBZLY-2012-BY7662
# ECLI-NL-CBB-2018-187
# ECLI-NL-RBNNE-2013-BZ7376
# ECLI-NL-RBLIM-2015-3472
# ECLI-NL-GHSHE-2021-3205
# ECLI-NL-RBZWB-2019-1589
# ECLI-NL-RBDHA-2016-5035
# ECLI-NL-RBAMS-2015-1442
# ECLI-NL-RBAMS-2015-1449
# ECLI-NL-RBGEL-2015-1670
# ECLI-NL-PHR-2014-2702
# ECLI-NL-RBAMS-2005-AT0873
# ECLI-NL-PHR-2022-374
# ECLI-NL-PHR-2006-AU8940
# ECLI-NL-RBOVE-2016-2791
# ECLI-NL-RBNHO-2014-1968
# ECLI-NL-RBMNE-2022-2525
# ECLI-NL-PHR-2008-BD4153
# ECLI-NL-RBUTR-2008-BD6957
# ECLI-NL-RBMNE-2022-2461
# ECLI-NL-GHSHE-2016-5164
# ECLI-NL-GHARL-2023-347
# ECLI-NL-RBOVE-2021-4198
# ECLI-NL-GHDHA-2018-1917
# ECLI-NL-RBAMS-2017-5516
# ECLI-NL-RBMAA-2011-BR0736
# ECLI-NL-GHSHE-2022-232
# ECLI-NL-GHSHE-2022-3199
# ECLI-NL-RBSHE-2010-BM9713
# ECLI-NL-GHARL-2013-8810
# ECLI-NL-RBUTR-2011-BP5092
# ECLI-NL-GHAMS-2007-BB2447
# ECLI-NL-RBAMS-2013-1291
# ECLI-NL-RBLIM-2018-3094
# ECLI-NL-RBAMS-2019-4555
# ECLI-NL-GHARL-2023-348
# ECLI-NL-RBAMS-2020-6166
# ECLI-NL-PHR-2016-1049
# ECLI-NL-PHR-2022-372
# ECLI-NL-RBAMS-2014-1159
# ECLI-NL-PHR-2022-373
# ECLI-NL-PHR-2017-1288
# ECLI-NL-PHR-2010-BM0976
# ECLI-NL-RVS-2018-249
# ECLI-NL-RBMNE-2022-2541
# ECLI-NL-RBMNE-2022-2403
# ECLI-NL-RBOBR-2018-6341
# ECLI-NL-PHR-2020-593
# ECLI-NL-RBUTR-2011-BP7250
# ECLI-NL-RBGEL-2016-3532
# ECLI-NL-GHAMS-2017-2618
# ECLI-NL-RBMNE-2022-2562
# ECLI-NL-RBGEL-2022-7105
# ECLI-NL-RBDHA-2019-4229
# ECLI-NL-GHSHE-2018-4181
# ECLI-NL-GHARL-2013-8827
# ECLI-NL-GHAMS-2005-AT9964
# ECLI-NL-PHR-2003-AH9922
# ECLI-NL-PHR-2021-75
# ECLI-NL-RBDHA-2016-5209
# ECLI-NL-RBNHO-2013-10924
# ECLI-NL-RBMNE-2021-221
# ECLI-NL-RBAMS-2013-BZ0392
# ECLI-NL-RBUTR-2011-BP6711
# ECLI-NL-PHR-2021-70
# ECLI-NL-PHR-2021-67
# ECLI-NL-PHR-2021-73
# ECLI-NL-PHR-2021-71
# ECLI-NL-PHR-2021-74
# ECLI-NL-PHR-2021-72
# 14676 records found.
# Finished

# %%
def clean_string(dirty):
    
    clean_str = dirty.strip()
    clean_str = clean_str.lower()
    
    return clean_str

# %% [markdown]
# ## Creating dataframe from extracted cases
# This code reads the text files in the directory location_cases and creates a data frame that contains the id of the file (case_id) and the text from the file (case text). It then merges this data frame with an existing data frame read from a CSV file(initial_dataset.csv). It then cleans the data frame by removing the dutch stopwords from the case text. It then calculates the total number of words in the uncleaned data frame and cleaned data frame, calculates the difference between the two, and prints the percentage decrease in the number of words.

# %%
dataPath = location_cases
if os.path.isfile(dataPath + ".DS_Store"):
    os.remove(dataPath + ".DS_Store")

verdict_df = pd.DataFrame(columns=["id", "case text"])

for filename in os.listdir(dataPath):
    id = filename.replace('.txt','')
    if id in verdict_df['id'].values:
        print(f"{id} already exists, skipping")
        continue
    with open(os.path.join(dataPath, filename), encoding='utf-8') as f:
        case_text = f.read()
        verdict_df = verdict_df.append({"id": id, "case text": case_text}, ignore_index=True)

cases_df = pd.read_csv(location_initial_dataset+'initial_dataset.csv')
merged_df = cases_df.join(verdict_df.set_index('id'), on='id', how='left')

merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"], dayfirst=True)
merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"], dayfirst=True)

total_len_uncleaned = 0
for i in range(len(merged_df)):
    currtext = merged_df.iloc[i]["case text"]
    try:
        length = len(currtext.split())
        total_len_uncleaned += length
    except:
        print('Please update the dataset')
        print(merged_df.iloc[i]["id"])
print(f"Total words in uncleaned dataset: {total_len_uncleaned}")

cleaned_df = merged_df.copy()
cleaned_df['case text'] = cleaned_df['case text'].apply(lambda x: ' '.join([word for word in x.split() if word not in dutch_stopwords]))
#print("Done")


total_len_cleaned = 0
for i in range(len(cleaned_df)):
    currtext = cleaned_df.iloc[i]["case text"]
    length = len(currtext.split())
    total_len_cleaned += length

print(f"Original count: {total_len_uncleaned} \n Cleaned count: {total_len_cleaned} \n Difference: {total_len_uncleaned - total_len_cleaned}")
print(f"{round((total_len_uncleaned - total_len_cleaned) / total_len_uncleaned * 100, 2)}% decrease")
# Out:
# Total words in uncleaned dataset: 81276005
# Original count: 81276005
#  Cleaned count: 48692535
#  Difference: 32583470
# 40.09% decrease

# %% [markdown]
# ## Creating list of cities in the Netherlands and common drug names
# This code is used to create a list of cities in the Netherlands by extracting data from a geonames.org website. It then takes the names of these cities and appends them to a list. It also has a list of common drug names that are also used in the script.

# %%
### RUN FROM HERE

# %%
# Create a list of cities in the Netherlands
url = "https://download.geonames.org/export/dump/NL.zip"
file_name = "NL.txt"

with zipfile.ZipFile(io.BytesIO(requests.get(url).content)) as archive:
    df = pd.read_csv(archive.open(file_name), sep='\t', header=None, names=['geonameid','name','asciiname','alternatenames','latitude','longitude','feature_class','feature_code','country_code','cc2','admin1_code','admin2_code','admin3_code','admin4_code','population','elevation','dem','timezone','modification_date'])

samall_cities = df[df['feature_code'] == 'PPL']['name'].tolist()
big_cities = df[(df['feature_code'].isin(['PPL','PPLA','PPLA2'])) & (df['population']>=100000)]['name'].tolist()
extra_cities = ['Leeuwarden','s-Gravenhage','Amsterdam', "Den Haag","Assen"]
cities = samall_cities + big_cities + extra_cities
#print(cities)

drugs = ["hennep", "wiet", "mdma", "xtc", "cocaïne", "cocaine", "heroïne", "heroine", "mefedron","4-mmc", "ketamine", "crack", "speed", "hasj",
"hasjiesj", "xtc-pillen", "amfetamine", "4-fluoramfetamine", "ghb", "gbl", "methamfetamine", "ecstasy","Paddo's", "Trimboline", "Poppers", "2CB", "Krokodil", "Fentanyl", "JWH-018", "MDPV", "Meow Meow", "N-Bomb", "Nitrieten", "GHB", "GBL", 
"Zoplicon","Zolpidem","Barbituraten","diamorfine","diazepam","captagon","isosafrol","benzylmethylketon","temazepam","codeine","PMK",
"ethylacetate","34-Methyleendioxymetamfetamine","apaen","psilocybine","MDMA-HCL","aceton","BMK.6","amfetamine.2",
"piperonal","mierenzuur","bmk-olie","psilocine","lidocaïne","methadon","MDMA-poeder","MDEA","manitol","amfetamine/metamfetamine","hash",
"MDMA-kristallen","4-fa","piperonylmethylKeton","hashish","amfetaminepasta","fenacetine","xtc-tabletten","crystal",
"MDMA-pillen","amfetamine-sulfaat","coffeïne","amfetamineolie","34-methyleendioxymethamfetamine","2c-b","meth","coffeïne",
"diacetylmorfine","mdea","4-fmp","benzylmorfine","codeïne","dexamfetamine","diamorfine","metamfetamine","methamfetamine","methamphetmine",
"metamphetamine","methylfenidaat","oxycodon","formic acid","tenamfetamine","piperonal","ethylacetaat","captagon",
"34-Methyleendioxymetamfetamine","formamide","isosafrol","bmk","pmk","aceton","amfetamine-olie",
"formamide","tenamfetamine","isosafrol","piperonal","mdma/xtc","ethylacetaat","captagon","34-Methyleendioxymetamfetamine","bmk-olie",
"formic acid","aceton","methanol"]


month_dict = {"januari": "january", "februari": "february", "maart": "march", "april": "april", "mei": "may", "juni": "june", "juli": "july",
"augustus": "august", "september": "september", "oktober": "october", "november": "november", "december": "december"}

# %% [markdown]
# ## Analysing Court cases using Regular Expressions
#
# It defines a number of regular expressions to search for specific information in the DataFrame Cleaned_df which include the informatioon about court cases. The code then uses a for loop to iterate over each row of the DataFrame and uses the regular expressions to extract information such as the crime date, birth year, location of the crime, and whether the crime is related to drugs or a criminal organization. The extracted information is then added as new columns to the DataFrame, and saved as final data frame. Additionally, it creates variables to count the number of age under 23, cases with location and drug cases.

# %%
# Create an empty DataFrame to store the filtered cases
trafficking_df = pd.DataFrame()

total_age_under_23 = 0
cases_with_location = 0
drug_cases = 0
start_time = time.time()

#### Define regular expressions for finding relevant information

# This pattern searches for the string "TENLASTELEGGING" followed by any number of characters (.*?) 
# then looks for a date in the format "dd Month yyyy" where "Month" can be any 3-9 character month name
crime_date_pattern = re.compile(r'tenlastelegging .*?([0-9]{1,2} [a-zA-Z]{3,9} [0-9]{4})\s', re.IGNORECASE| re.DOTALL)

# This pattern searches for the string "verdachte" followed by any number of characters (.*?) 
# then looks for 4 digits (\d{4})
birth_year_pattern = re.compile(r"verdachte.*?(\d{4})\s", re.IGNORECASE| re.DOTALL)

# This pattern searches for the word "rechtbank" followed by any number of whitespaces (\b\s*)
# and any non-whitespace characters (\S+)
rechtbank_pattern = re.compile(r'\brechtbank\b\s*(\S+)', re.IGNORECASE| re.DOTALL)

# This pattern searches for the word "zittingsplaats" followed by any number of whitespaces (\b\s*)
# and any non-whitespace characters (\S+)
zittingsplaats_pattern = re.compile(r'\bzittingsplaats\b\s*(\S+)', re.IGNORECASE| re.DOTALL)

# This pattern searches for terms such as "criminele organisatie"
criminal_organization_pattern = r'criminele organisatie|georganiseerde criminaliteit|georganiseerde misdaad|crimineel samenwerkingsverband|groepscriminaliteit'

# This pattern searches for the word "gerechtshof" followed by any number of whitespaces (\b\s*)
# and any non-whitespace characters (\S+)
gerechtshof_pattern = re.compile(r'\bgerechtshof\b\s*(\S+)', re.IGNORECASE| re.DOTALL)


# Iterate over rows
for i in range(len(cleaned_df)):
    curr = cleaned_df.iloc[i]
    uitspraak = curr["case text"]
    verdict_date = curr["verdict_date"]
    jurisdiction_type = curr["jurisdiction_type"]
    drug_found = False
    crime_location_found = False
    
    try:
        # Find crime date
        crime_date_match = crime_date_pattern.search(uitspraak)
        crime_date = crime_date_match.group(1)        
        
        # Convert the "crime_date" column to a datetime object and extract the month and year
        for key, value in month_dict.items(): crime_date = crime_date.replace(key, value)
        curr['crime_date'] = crime_date    
        curr["crime_date"] = pd.to_datetime(curr['crime_date'], format='%d %B %Y')
        curr["crime_month"] = curr["crime_date"].month_name()
        curr["crime_year"] = curr["crime_date"].year

        # Convert the "verdict_date" column to a datetime object and extract the month and year        
        curr["verdict_date"] = pd.to_datetime(curr['verdict_date'], format='%d %B %Y')
        curr["verdict_month"] = curr["verdict_date"].month_name()
        curr["verdict_year"] = curr["verdict_date"].year        
        
        # Find birth year
        birth_year_match = birth_year_pattern.search(uitspraak)
        birth_year = birth_year_match.group(1)
        
        #calculates the age of the suspect    
        age = int(curr["crime_year"]) - int(birth_year)
          
        if age >= 10 and age <= 23:
            total_age_under_23 += 1
            
        if not (age >= 10 and age <= 23):
            age = 0
            
        curr["age"] = age 
        
        #Find existence of criminal organization in case text
        organization_search = re.search(criminal_organization_pattern, uitspraak, flags=re.IGNORECASE)
        if organization_search:
            curr["criminal_organization"] = 1
        else:
            curr["criminal_organization"] = 0        
        
        
        # Find rechtbank
        rechtbank_match = rechtbank_pattern.search(uitspraak)
        if rechtbank_match:
            rechtbank = rechtbank_match.group(1)
            if rechtbank.lower().startswith('den'):
                rechtbank = 'Den Haag'
            curr['rechtbank'] = rechtbank  
             
            
        # Find zittingsplaats
        zittingsplaats_match = zittingsplaats_pattern.search(uitspraak)
        if zittingsplaats_match:
            zittingsplaats = zittingsplaats_match.group(1)
            if zittingsplaats in cities: # check if location is in the list of cities
                curr['zittingsplaats'] = zittingsplaats
                
                
        # Find gerechtshof
        gerechtshof_match = gerechtshof_pattern.search(uitspraak)        
        if gerechtshof_match:
            curr['hoger_beroep'] = 1
            gerechtshof = gerechtshof_match.group(1) 
            if gerechtshof.lower().startswith('den'):
                gerechtshof = 'Den Haag'            
            curr['gerechtshof'] = gerechtshof            
        else:
            curr['hoger_beroep'] = 0                 
            
        
        # Find crime location
        for crime_location in cities:
            crime_location_search = re.match(crime_location, uitspraak[crime_date_match.end():])
            if crime_location_search and not crime_location_found:
                curr["crime_location"] = crime_location
                crime_location_found = True
                cases_with_location += 1                
                break       
                 
        # Find drug type in cases
        for drug in drugs:
            drug_search = re.search(drug, uitspraak, flags=re.IGNORECASE)
            if drug_search and not drug_found:
                curr["drug_type"] = drug
                drug_found = True
                drug_cases += 1
                break
                
        # Cases met more than one drug type                
        found_drugs = []
        for drug in drugs:
            drug_search = re.search(drug, uitspraak, flags=re.IGNORECASE)
            if drug_search:
                found_drugs.append(drug)
        curr["drugs"] = found_drugs                    
        curr["case text"] = curr["case text"][:5000] # truncate to 5000 characters
        trafficking_df = trafficking_df.append(curr)
        
    except:
       
        pass

# %%
end_time = time.time()
duration = end_time - start_time
duration = timedelta(seconds=duration)
duration = timedelta(seconds=round(duration.total_seconds()))

print(f"Total cases used for the filtering: {len(cleaned_df)}")
print(f"Total cases filterd:  {len(trafficking_df)} cases.")
print("Total cases that has crime location: ", cases_with_location) 
print(f"Total cases that has drug: {drug_cases}")
print(f"Total cases with suspects aged under 23: {total_age_under_23}")
print(f"Duration: ", duration.seconds//60, "minutes and", duration.seconds%60, "seconds")
# Out:
# Total cases used for the filtering: 14676
# Total cases filterd:  10171 cases.
# Total cases that has crime location:  2602
# Total cases that has drug: 7969
# Total cases with suspects aged under 23: 990
# Duration:  33 minutes and 26 seconds

# %% [markdown]
# ## Creating the final data set
# This code performs several operations on the data frame. First, it removes cases (rows) that has no drugs. Next, it is using the drop() function to remove the 'case text', 'inhoudsindicatie', and 'drugs' columns from the dataframe. Then, it is using the replace() method to replace all occurrences of the strings "wiet", "Hennep", and "hennep/wiet" with the string "hennep" in the "drug_type" column.

# %%
final_df = trafficking_df.copy()

# %%
### 
### If there is empty age value, flag minor as 0

final_df['age'] = final_df['age'].replace(0.0, pd.np.nan)
final_df['minor'] = final_df['age'].apply(lambda x: 1 if x < 18 else 0)

# %%
final_df['hoger_beroep'] = final_df['hoger_beroep'].astype(int)
final_df['criminal_organization'] = final_df['criminal_organization'].astype(int)

# %%
### Drop irrelevant columns and rename column for visualizations

cols_to_drop = ['crime_month', 'crime_year', 'verdict_month', 'verdict_year', 'drug_type']
final_df.drop(columns=cols_to_drop, inplace=True) 
final_df = final_df.rename(columns={'drugs':'drug_type'})
final_df = final_df.rename(columns={'hoger_beroep':'appeal'})

# %%
### The date columns were not correctly extracted
### So lets extract them correctly

final_df['crime_date_month'] = pd.to_datetime(final_df['crime_date'], errors='coerce')
final_df['crime_date_month'] = final_df['crime_date_month'].dt.month
final_df['crime_date_year'] = pd.to_datetime(final_df['crime_date'], format='%d-%m-%Y').dt.year

final_df['verdict_date_month'] = pd.to_datetime(final_df['verdict_date'], errors='coerce')
final_df['verdict_date_month'] = final_df['verdict_date'].dt.month
final_df['verdict_date_year'] = pd.to_datetime(final_df['verdict_date'], format='%d-%m-%Y').dt.year

# %%
### Rename crime_date_month column to categorical values
### Rename verdict_date_month column to categorical values

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
final_df['crime_date_month'] = final_df['crime_date_month'].map(lambda x: months[x-1])
final_df['verdict_date_month'] = final_df['verdict_date_month'].map(lambda x: months[x-1])

# %%
final_df = final_df.reset_index(drop=True)
cols = [
    'id', 
    'jurisdiction_type', 
    'rechtbank',
    'gerechtshof', 
    'appeal',
    'crime_location', 
    'verdict_date_year', 
    'verdict_date_month',
    'crime_date_month', 
    'crime_date_year', 
    'age', 
    'minor',
    'criminal_organization', 
    'drug_type'
]
final_df = final_df.reindex(columns=cols)

# %%
### Transform to lower case

final_df['drug_type'] = final_df['drug_type'].apply(lambda x: [i.lower() for i in x])
columns_to_transform = ['rechtbank', 'gerechtshof', 'crime_location', 'verdict_date_month', 'crime_date_month']
for col in columns_to_transform:
    final_df[col] = final_df[col].str.lower()

# %%
### Function to remove synonyms
### At the drug list above, we also dropped some irrelevant drug types like 'paracetemol', 'pillen', 'pil', 'caffeine' etc.

def standardize_drugs(df, column_name):
    replace_list = {
        "cocaïne":"cocaine",
        "heroïne":"heroine",
        "metamfetamine":"amfetamines/metamfetamines",
        "methamfetamine":"amfetamines/metamfetamines",
        "methamphetmine":"amfetamines/metamfetamines",
        "crystal":"amfetamines/metamfetamines",
        "speed":"amfetamines/metamfetamines",
        "meth":"amfetamines/metamfetamines",
        "methylfenidaat":"amfetamines/metamfetamines",
        "metamphetamine":"amfetamines/metamfetamines",
        "amfetamine":"amfetamines/metamfetamines",
        "metamphetamine":"amfetamines/metamfetamines",
        "amfetamine-sulfaat":"amfetamines/metamfetamines",
        "amfetamine.2":"amfetamines/metamfetamines",
        "amfetamine.7":"amfetamines/metamfetamines",
        "amfetamine-olie":"amfetamines/metamfetamines",
        "amfetamine/metamfetamine":"amfetamines/metamfetamines",
        "meth":"amfetamines/metamfetamines",
        "amfetamineolie":"amfetamines/metamfetamines",
        "amfetaminepasta":"amfetamines/metamfetamines",
        "34-methyleendioxymetamfetamine":"amfetamines/metamfetamines",
        "34-methyleendioxymethamfetamine":"amfetamines/metamfetamines",
        "mdma-pillen":"mdma",
        "mdma-poeder":"mdma",
        "mdma-kristallen":"mdma",
        "mdma-poeder":"mdma",
        "xtc-pillen":"xtc",
        "xtc-tabletten":"xtc",
        "ecstasy":"xtc",
        "ecstasy-pillen":"xtc",
        "codeïne":"codeine",
        "bmk.6":"bmk",
        "bmk-olie":"bmk",
        "bmk-olie.6":"bmk",
        "hasj":"hasjiesj",
        "hashish":"hasjiesj",
        "hash":"hasjiesj",
        "wiet":"hennep"
        
    }
    df[column_name] = df[column_name].apply(lambda x: list(set([replace_list.get(i, i) for i in x])))
    return df

# %%
### Apply function to standardize drugs
final_df = standardize_drugs(final_df, 'drug_type')

### Drop cases that have an empty drugs list
final_df = final_df[final_df['drug_type'].apply(lambda x: len(x) > 0)].reset_index(drop=True)

# %%
### Check for duplicates

final_df.groupby('id').size().sort_values(ascending=False).reset_index(name='counts').head()
# Out:
#                         id  counts
# 0     ECLI-NL-CBB-2018-187       1
# 1  ECLI-NL-RBNNE-2016-2297       1
# 2  ECLI-NL-RBNNE-2016-2847       1
# 3  ECLI-NL-RBNNE-2016-2747       1
# 4  ECLI-NL-RBNNE-2016-2654       1

# %%
final_df
# Out:
#                              id                     jurisdiction_type  \
# 0       ECLI-NL-RBDHA-2019-9384                        ['Strafrecht']
# 1       ECLI-NL-RBMNE-2014-7289  ['Strafrecht; Materieel strafrecht']
# 2     ECLI-NL-RBUTR-2008-BG6691                        ['Strafrecht']
# 3       ECLI-NL-RBNNE-2013-1693                        ['Strafrecht']
# 4       ECLI-NL-RBAMS-2015-3865                        ['Strafrecht']
# ...                         ...                                   ...
# 7964    ECLI-NL-RBDHA-2016-5209                        ['Strafrecht']
# 7965   ECLI-NL-RBNHO-2013-10924                        ['Strafrecht']
# 7966     ECLI-NL-RBMNE-2021-221                        ['Strafrecht']
# 7967  ECLI-NL-RBAMS-2013-BZ0392                        ['Strafrecht']
# 7968  ECLI-NL-RBUTR-2011-BP6711                        ['Strafrecht']
#
#              rechtbank gerechtshof  appeal crime_location  verdict_date_year  \
# 0             den haag         NaN       0            NaN               2019
# 1     midden-nederland         NaN       0            NaN               2014
# 2              utrecht         NaN       0            NaN               2008
# 3      noord-nederland         NaN       0            NaN               2013
# 4            amsterdam         NaN       0            NaN               2015
# ...                ...         ...     ...            ...                ...
# 7964          den haag    den haag       1            NaN               2016
# 7965     noord-holland   amsterdam       1            NaN               2013
# 7966  midden-nederland         NaN       0            NaN               2021
# 7967         amsterdam   amsterdam       1            NaN               2013
# 7968           utrecht   amsterdam       1            NaN               2011
#
#      verdict_date_month crime_date_month  crime_date_year   age  minor  \
# 0                   jun              apr             2019  18.0      0
# 1                   apr              jan             2012   NaN      0
# 2                   sep              oct             2007   NaN      0
# 3                   feb              sep             2012   NaN      0
# 4                   may              dec             2012   NaN      0
# ...                 ...              ...              ...   ...    ...
# 7964                may              apr             2014  20.0      0
# 7965                nov              mar             2012   NaN      0
# 7966                jan              dec             2019   NaN      0
# 7967                jan              feb             2009   NaN      0
# 7968                feb              jan             2006   NaN      0
#
#       criminal_organization                                          drug_type
# 0                         0                                 [cocaine, heroine]
# 1                         0  [krokodil, hennep, 2c-b, mdma, amfetamines/met...
# 2                         0                               [cocaine, mdma, xtc]
# 3                         0                                  [cocaine, aceton]
# 4                         0                                    [cocaine, mdma]
# ...                     ...                                                ...
# 7964                      1                                         [hasjiesj]
# 7965                      1    [cocaine, amfetamines/metamfetamines, krokodil]
# 7966                      0              [poppers, amfetamines/metamfetamines]
# 7967                      1                       [amfetamines/metamfetamines]
# 7968                      1                                              [gbl]
#
# [7969 rows x 14 columns]

# %% [markdown]
# ### Explode dataframe

# %%
### Explode and check unique drug types

final_df_exploded = final_df.explode('drug_type').reset_index(drop=True)
print(final_df_exploded['drug_type'].unique())
# Out:
# ['cocaine' 'heroine' 'krokodil' 'hennep' '2c-b' 'mdma'
#  'amfetamines/metamfetamines' 'methadon' 'xtc' 'mefedron' 'aceton'
#  'diacetylmorfine' 'crack' 'hasjiesj' 'tenamfetamine' 'mdea' 'fenacetine'
#  'methanol' 'coffeïne' 'ketamine' 'ghb' 'gbl' 'fentanyl'
#  'benzylmethylketon' 'bmk' 'mierenzuur' 'formamide' 'pmk' '4-fa'
#  '4-fluoramfetamine' 'formic acid' 'manitol' 'isosafrol' 'diazepam' '2cb'
#  'temazepam' 'mdma/xtc' 'ethylacetaat' 'ethylacetate'
#  'piperonylmethylketon' 'lidocaïne' '4-mmc' 'piperonal' 'mdma-hcl'
#  'codeine' 'oxycodon' 'dexamfetamine' 'zolpidem' 'psilocine' 'psilocybine'
#  'poppers' 'captagon' 'barbituraten' 'zoplicon' 'diamorfine' '4-fmp'
#  "paddo's"]

# %% [markdown]
# ### Import juvenile cases

# %%
df_jeugdstrafrecht = pd.read_csv("final_df_unique.csv")
df_jeugdstrafrecht = df_jeugdstrafrecht[['id', 'jurisdiction_type']]
df_jeugdstrafrecht
# Out:
#                             id jurisdiction_type
# 0      ECLI-NL-RBDHA-2019-9384    ['Strafrecht']
# 1      ECLI-NL-GHAMS-2020-1930    ['Strafrecht']
# 2       ECLI-NL-GHAMS-2022-115    ['Strafrecht']
# 3       ECLI-NL-RBNNE-2023-118    ['Strafrecht']
# 4      ECLI-NL-RBROT-2019-4815    ['Strafrecht']
# ..                         ...               ...
# 156    ECLI-NL-RBMNE-2020-4495    ['Strafrecht']
# 157    ECLI-NL-RBLIM-2017-3317    ['Strafrecht']
# 158    ECLI-NL-RBOVE-2021-4198    ['Strafrecht']
# 159    ECLI-NL-RBMNE-2020-4872    ['Strafrecht']
# 160  ECLI-NL-RBMAA-2011-BR0736    ['Strafrecht']
#
# [161 rows x 2 columns]

# %%
df_jeugdstrafrecht['jurisdiction_type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Join dataframes

# %%
### Left join total cases with juvenile cases
### Empty values are not juvenile cases

df_merged = final_df.merge(df_jeugdstrafrecht, on="id", how="left")

# %%
df_merged['jeugdstrafrecht'] = df_merged.apply(lambda x: 1 if pd.notnull(x['jurisdiction_type_y']) else 0, axis=1)

# %%
df_merged
# Out:
#                              id                   jurisdiction_type_x  \
# 0       ECLI-NL-RBDHA-2019-9384                        ['Strafrecht']
# 1       ECLI-NL-RBMNE-2014-7289  ['Strafrecht; Materieel strafrecht']
# 2     ECLI-NL-RBUTR-2008-BG6691                        ['Strafrecht']
# 3       ECLI-NL-RBNNE-2013-1693                        ['Strafrecht']
# 4       ECLI-NL-RBAMS-2015-3865                        ['Strafrecht']
# ...                         ...                                   ...
# 7964    ECLI-NL-RBDHA-2016-5209                        ['Strafrecht']
# 7965   ECLI-NL-RBNHO-2013-10924                        ['Strafrecht']
# 7966     ECLI-NL-RBMNE-2021-221                        ['Strafrecht']
# 7967  ECLI-NL-RBAMS-2013-BZ0392                        ['Strafrecht']
# 7968  ECLI-NL-RBUTR-2011-BP6711                        ['Strafrecht']
#
#              rechtbank gerechtshof  appeal crime_location  verdict_date_year  \
# 0             den haag         NaN       0            NaN               2019
# 1     midden-nederland         NaN       0            NaN               2014
# 2              utrecht         NaN       0            NaN               2008
# 3      noord-nederland         NaN       0            NaN               2013
# 4            amsterdam         NaN       0            NaN               2015
# ...                ...         ...     ...            ...                ...
# 7964          den haag    den haag       1            NaN               2016
# 7965     noord-holland   amsterdam       1            NaN               2013
# 7966  midden-nederland         NaN       0            NaN               2021
# 7967         amsterdam   amsterdam       1            NaN               2013
# 7968           utrecht   amsterdam       1            NaN               2011
#
#      verdict_date_month crime_date_month  crime_date_year   age  minor  \
# 0                   jun              apr             2019  18.0      0
# 1                   apr              jan             2012   NaN      0
# 2                   sep              oct             2007   NaN      0
# 3                   feb              sep             2012   NaN      0
# 4                   may              dec             2012   NaN      0
# ...                 ...              ...              ...   ...    ...
# 7964                may              apr             2014  20.0      0
# 7965                nov              mar             2012   NaN      0
# 7966                jan              dec             2019   NaN      0
# 7967                jan              feb             2009   NaN      0
# 7968                feb              jan             2006   NaN      0
#
#       criminal_organization  \
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 7964                      1
# 7965                      1
# 7966                      0
# 7967                      1
# 7968                      1
#
#                                               drug_type jurisdiction_type_y  \
# 0                                    [cocaine, heroine]      ['Strafrecht']
# 1     [krokodil, hennep, 2c-b, mdma, amfetamines/met...                 NaN
# 2                                  [cocaine, mdma, xtc]                 NaN
# 3                                     [cocaine, aceton]                 NaN
# 4                                       [cocaine, mdma]                 NaN
# ...                                                 ...                 ...
# 7964                                         [hasjiesj]                 NaN
# 7965    [cocaine, amfetamines/metamfetamines, krokodil]                 NaN
# 7966              [poppers, amfetamines/metamfetamines]                 NaN
# 7967                       [amfetamines/metamfetamines]                 NaN
# 7968                                              [gbl]                 NaN
#
#       jeugdstrafrecht
# 0                   1
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 7964                0
# 7965                0
# 7966                0
# 7967                0
# 7968                0
#
# [7969 rows x 16 columns]

# %%
df_merged['jeugdstrafrecht'].value_counts()
# Out:
# 0    7808
# 1     161
# Name: jeugdstrafrecht, dtype: int64

# %%
df_merged.to_csv('df_merged.csv', index=False)
